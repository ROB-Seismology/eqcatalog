# %%
import folium
import eqcatalog

# %%
eq_id = 6625
[eq] = eqcatalog.rob.seismodb.query_local_eq_catalog_by_id(eq_id)
dyfi = eq.get_online_macro_enquiries()

# %%
dyfi.get_addresses()[:100]
# Out:
# [u'KEMPENSTRAAT 1, 3700 TONGEREN, BE',
#  u'BUVINGENSTRAAT, NIEL-BIJ-ST.-TRUIDEN, 3890 GINGELOM, BE',
#  u'WINTERBERGSTRAAT, 3740 BILZEN, BE',
#  u'RUE SOUS LE CHATEAU 56, 4300 WAREMME, BE',
#  u'',
#  u'KORENBLOEMSTRAAT 10., 3700 TONGEREN, BE',
#  u'BURGENMEESTER DEWALQUENSTRAAT, 3770 RIEMST, BE',
#  u'SCHIPPERDSTRAAT 15, 3620 LANAKEN, BE',
#  u'CHAUSSEE DES GRENADIERS EBEN EMAEL, 4690 BASSENGE, BE',
#  u'LOOSTRAAT, 3724 VLIERMAAL, BE',
#  u'',
#  u'BODEMSTRAAT, 3770 RIEMST, BE',
#  u'',
#  u'KASTEELSTRAAT, 3740 BILZEN, BE',
#  u'',
#  u'RUE DE LA CENTENAIRE 26, 4360 OREYE, BE',
#  u'',
#  u'',
#  u'HONSDRIES 14, 3640 OPHOVEN, BE',
#  u'',
#  u'MELLEVELDSTRAAT, 3730 , BE',
#  u'HOEVEEKERKWEG 53, 3660 OPGLABBEEK, BE',
#  u'RUE LENOIR 9, 4350 MOMALLE, BE',
#  u'KEISTRAAT, 3740 BILZEN, BE',
#  u'LINDEBOSSTRAAT 56, 3600 GENK, BE',
#  u'RONDESTRAAT (LOZEN), 3950 BOCHOLT, BE',
#  u'SPARRENLAAN 8, 3730 HOESELT, BE',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'BORGOGNESTRAAT 18, 6221 MAASTRICHT, NL',
#  u'PETER BENOITSTRAAT 64A, 3500 HASSELT, BE',
#  u'MEREMWAG 29, 3740 BILZEN, BE',
#  u'',
#  u'KEISTRAAT 5   KLEINE SPOUWEN (BILZEN), 3740 3740 KLEINE SPOUWEN (BILZEN), BE',
#  u'TOMSTRAAT 56, 3700 TONGEREN, BE',
#  u'',
#  u'KERKSTRAAT 39, 3960 BREE, BE',
#  u'SCHILLINGSSTRAAT 48, 3680 MAASEIK, BE',
#  u'WEIENHOUT 19, 3600 GENK, BE',
#  u'KLOOSTERSTRAAT 14 TE, 3960 BREE, BE',
#  u'GREMERSLOWEG 7A, 3680 MAASEIK, BE',
#  u'BARENZAALLAAN TE GENK, 3600 HENK, BE',
#  u'SCHUTTERIJSTRAAT, 3530 HELCHTEREN, BE',
#  u'DIAMANTSTRAAT, 3960 BREE, BE',
#  u'BORNSTRAAT 56, 3721 KORTESSEM, BE',
#  u'KLEINESTRAAT 40, 3640 MOLENBEERSEL, BE',
#  u'LANGENSVELD 17, 3960 BREE, BE',
#  u'',
#  u'MAASTRICHTERSTEENWEG, 3700 TONGEREN, BE',
#  u'',
#  u'',
#  u'HAGERWEG 14, 3680 NEEROETEREN, BE',
#  u'BOSSTRAAT6, 3770 RIEMST, BE',
#  u'',
#  u'IDA VAN BOLENSTRAAT 30, 3740 MUNSTERBILZEN, BE',
#  u'BIESTERTSTRAAT 54, 3740 BILZEN, BE',
#  u'GRUITRODERKIEZEL 258, 3960 BREE, BE',
#  u'GROENENDAAL 3, 3740 WALTWILDER-BILZEN, BE',
#  u'PATER CONINXLAAN, 3960 BREE, BE',
#  u'BOVELINGENSTRAAT, 3870 HEERS, BE',
#  u'',
#  u'AMBIORIXLAAN, 3621 LANAKEN, BE',
#  u'LINDEKAPELSTRAAT 28, 3730 HOESELT, BE',
#  u'DORPSPLEIN 5 BUS 2, 3640 KINROOI, BE',
#  u'MOSKESSTRAAT 23, 3090 OVERIJSE, BE',
#  u'',
#  u'EIKENENPAD, 3520 ZONHOVEN, BE',
#  u'',
#  u'WEG NAAR AS 160, 3660 OPGLABBEEK, BE',
#  u'VENNENDIJK 20A, 3680 NEEROETEREN, BE',
#  u'',
#  u'RUE NEUVE, 6, 4351 HODEIGE, BE',
#  u'GROTE STRAAT, 3770 VAL-MEER, BE',
#  u'HOOGSTRAAT , GORS OP LEEUW, 3840 BORGLOON, BE',
#  u'11/6, 3910 NEERPELT, BE',
#  u'(ALDENEIK), 3680 MAASEIK, BE',
#  u'GROTE KERKSTRAAT, 3680 MAASEIK, BE',
#  u'',
#  u'PERKESTRAAT, 3700 TONGEREN, BE',
#  u'NEEROETERENSTAAT, 3680 OPOETEREN, BE',
#  u'KEVERSTRAAT, 3700 TONGEREN, BE',
#  u'KAREL GESSLERSTRAAT 50, 3680 MAASEIK, BE',
#  u'HEUVELERWEG, 3910 NEERPELT, BE',
#  u'RODE KRUISLAAN, 28, 3960 BREE, BE',
#  u'HUBESHEIDE 3, 3960 BREE, BE',
#  u'MILLENSTRAAT 22 BUS 2/1, 3960 BREE, BE',
#  u'WEERTERSTEENWEG 151, 3680 MAASEIK, BE',
#  u'SCHANSBROEKSTRAAT 59, 3600 GENK, BE',
#  u'',
#  u'KORENWAL, 3740 BILZEN, BE',
#  u'DIKKE LINDE OPHOVEN (KINROOI), 3640 , BE',
#  u'WUYTENWEG, 3900 OVERPELT, BE',
#  u'',
#  u'SERVAASPLEIN, 3590 , BE',
#  u'SINT-TRUIDERSTEENWEG, 3840 BORGLOON, BE',
#  u'',
#  u'LIEPENSWEG 13, 3770 VLIJTINGEN, BE',
#  u'BOCHOLTERKIEZEL 17 B, 3960 BREE, BE']

# %%
provider = "arcgis"
from secrets.here_api_key import app_id, app_code
bbox = [0, 48, 10, 52]
geo_results2 = dyfi.geocode(provider, bbox=bbox, app_id=app_id, app_code=app_code, max_requests=50)

# %%
for loc, address in zip(geo_results2, dyfi.get_addresses()):
    print(address)
    print(loc)
    print('')
# Out:
# KEMPENSTRAAT 1, 3700 TONGEREN, BE
# (5.4432423308040745, 50.77514451569615, 9)
#
# BUVINGENSTRAAT, NIEL-BIJ-ST.-TRUIDEN, 3890 GINGELOM, BE
# (5.149932115275461, 50.7427735434506, 9)
#
# WINTERBERGSTRAAT, 3740 BILZEN, BE
# (5.523253877549258, 50.83745056092791, 9)
#
# RUE SOUS LE CHATEAU 56, 4300 WAREMME, BE
# (5.252134709821726, 50.696868111575945, 9)
#
#
# ()
#
# KORENBLOEMSTRAAT 10., 3700 TONGEREN, BE
# (5.438913719833708, 50.766079599774976, 9)
#
# BURGENMEESTER DEWALQUENSTRAAT, 3770 RIEMST, BE
# (5.614681276054285, 50.796024743543185, 9)
#
# SCHIPPERDSTRAAT 15, 3620 LANAKEN, BE
# (5.675825739252088, 50.884867172369916, 9)
#
# CHAUSSEE DES GRENADIERS EBEN EMAEL, 4690 BASSENGE, BE
# (5.673252297450606, 50.80480681019756, 9)
#
# LOOSTRAAT, 3724 VLIERMAAL, BE
# (5.425427299985609, 50.844204305311656, 9)
#
#
# ()
#
# BODEMSTRAAT, 3770 RIEMST, BE
# (5.590097209970988, 50.79254543921681, 9)
#
#
# ()
#
# KASTEELSTRAAT, 3740 BILZEN, BE
# (5.520426031850768, 50.84266117007165, 9)
#
#
# ()
#
# RUE DE LA CENTENAIRE 26, 4360 OREYE, BE
# (5.3444512245368925, 50.722476442148874, 9)
#
#
# ()
#
#
# ()
#
# HONSDRIES 14, 3640 OPHOVEN, BE
# (5.79426205689884, 51.123255442148874, 9)
#
#
# ()
#
# MELLEVELDSTRAAT, 3730 , BE
# (5.478151680317109, 50.86988604855166, 9)
#
# HOEVEEKERKWEG 53, 3660 OPGLABBEEK, BE
# (5.586405525419647, 51.03826307882738, 9)
#
# RUE LENOIR 9, 4350 MOMALLE, BE
# (5.367299321686123, 50.6888380885509, 9)
#
# KEISTRAAT, 3740 BILZEN, BE
# (5.547865252740695, 50.84633693017857, 9)
#
# LINDEBOSSTRAAT 56, 3600 GENK, BE
# (5.544856774309265, 50.96351072494093, 9)
#
# RONDESTRAAT (LOZEN), 3950 BOCHOLT, BE
# (5.558511454256356, 51.20142397855189, 9)
#
# SPARRENLAAN 8, 3730 HOESELT, BE
# (5.484107823071111, 50.84554982041672, 9)
#
#
# ()
#
#
# ()
#
#
# ()
#
#
# ()
#
# BORGOGNESTRAAT 18, 6221 MAASTRICHT, NL
# (5.703151500000018, 50.84876700000001, 9)
#
# PETER BENOITSTRAAT 64A, 3500 HASSELT, BE
# (5.3522014755899585, 50.927953483495806, 9)
#
# MEREMWAG 29, 3740 BILZEN, BE
# (5.499569127935931, 50.86428688703907, 9)
#
#
# ()
#
# KEISTRAAT 5   KLEINE SPOUWEN (BILZEN), 3740 3740 KLEINE SPOUWEN (BILZEN), BE
# (5.546514241069736, 50.8444235523112, 9)
#
# TOMSTRAAT 56, 3700 TONGEREN, BE
# (5.4155214596053725, 50.78715394419769, 9)
#
#
# ()
#
# KERKSTRAAT 39, 3960 BREE, BE
# (5.60480614902776, 51.15774069830919, 9)
#
# SCHILLINGSSTRAAT 48, 3680 MAASEIK, BE
# (5.795644876911516, 51.093386328899484, 9)
#
# WEIENHOUT 19, 3600 GENK, BE
# (5.4640300900801035, 50.944802898147586, 9)
#
# KLOOSTERSTRAAT 14 TE, 3960 BREE, BE
# (5.59694734664444, 51.140232513185985, 9)
#
# GREMERSLOWEG 7A, 3680 MAASEIK, BE
# (5.750877340643169, 51.10474406497756, 9)
#
# BARENZAALLAAN TE GENK, 3600 HENK, BE
# (5.487311250000013, 50.982457499999995, 9)
#
# SCHUTTERIJSTRAAT, 3530 HELCHTEREN, BE
# (5.395411878502397, 51.058343954564435, 9)
#
# DIAMANTSTRAAT, 3960 BREE, BE
# (5.598474283851329, 51.151704588406076, 9)
#
# BORNSTRAAT 56, 3721 KORTESSEM, BE
# (5.434450501529221, 50.86917343493551, 9)
#
# KLEINESTRAAT 40, 3640 MOLENBEERSEL, BE
# (5.738611466991623, 51.17795027589579, 9)
#
# LANGENSVELD 17, 3960 BREE, BE
# (5.656128750000017, 51.12603000000001, 9)
#
#
# ()
#
# MAASTRICHTERSTEENWEG, 3700 TONGEREN, BE
# (5.529949309988819, 50.793031874356124, 9)
#
#
# ()
#
#
# ()
#
# HAGERWEG 14, 3680 NEEROETEREN, BE
# (5.688246189710847, 51.11016709576427, 9)
#
# BOSSTRAAT6, 3770 RIEMST, BE
# (5.587563126435381, 50.826992122684466, 9)
#
#
# ()
#
# IDA VAN BOLENSTRAAT 30, 3740 MUNSTERBILZEN, BE
# (5.5238391025735964, 50.89246496502972, 9)
#
# BIESTERTSTRAAT 54, 3740 BILZEN, BE
# (5.542994787668128, 50.83032814683472, 9)
#
# GRUITRODERKIEZEL 258, 3960 BREE, BE
# (5.592105442380031, 51.11796429225575, 9)
#
# GROENENDAAL 3, 3740 WALTWILDER-BILZEN, BE
# (5.546627775867143, 50.8768691806798, 9)
#
# PATER CONINXLAAN, 3960 BREE, BE
# (5.5905974323581145, 51.129337432358106, 9)
#
# BOVELINGENSTRAAT, 3870 HEERS, BE
# (5.277997393760857, 50.7544081325477, 9)
#
#
# ()
#
# AMBIORIXLAAN, 3621 LANAKEN, BE
# (5.6915285355129885, 50.9174353365868, 9)
#
# LINDEKAPELSTRAAT 28, 3730 HOESELT, BE
# (5.487728868428753, 50.84225557923141, 9)
#
# DORPSPLEIN 5 BUS 2, 3640 KINROOI, BE
# (5.741785175111226, 51.14479875076461, 9)
#
# MOSKESSTRAAT 23, 3090 OVERIJSE, BE
# (4.5990639225576215, 50.76907584595195, 9)
#
#
# ()
#
# EIKENENPAD, 3520 ZONHOVEN, BE
# (5.366874071605572, 50.996639460915034, 9)
#
#
# ()
#
# WEG NAAR AS 160, 3660 OPGLABBEEK, BE
# ()
#
# VENNENDIJK 20A, 3680 NEEROETEREN, BE
# ()
#
#
# ()
#
# RUE NEUVE, 6, 4351 HODEIGE, BE
# ()
#
# GROTE STRAAT, 3770 VAL-MEER, BE
# ()
#
# HOOGSTRAAT , GORS OP LEEUW, 3840 BORGLOON, BE
# ()
#
# 11/6, 3910 NEERPELT, BE
# ()
#
# (ALDENEIK), 3680 MAASEIK, BE
# ()
#
# GROTE KERKSTRAAT, 3680 MAASEIK, BE
# ()
#
#
# ()
#
# PERKESTRAAT, 3700 TONGEREN, BE
# ()
#
# NEEROETERENSTAAT, 3680 OPOETEREN, BE
# ()
#
# KEVERSTRAAT, 3700 TONGEREN, BE
# ()
#
# KAREL GESSLERSTRAAT 50, 3680 MAASEIK, BE
# ()
#
# HEUVELERWEG, 3910 NEERPELT, BE
# ()
#
# RODE KRUISLAAN, 28, 3960 BREE, BE
# ()
#
# HUBESHEIDE 3, 3960 BREE, BE
# ()
#
# MILLENSTRAAT 22 BUS 2/1, 3960 BREE, BE
# ()
#
# WEERTERSTEENWEG 151, 3680 MAASEIK, BE
# ()
#
# SCHANSBROEKSTRAAT 59, 3600 GENK, BE
# ()
#
#
# ()
#
# KORENWAL, 3740 BILZEN, BE
# ()
#
# DIKKE LINDE OPHOVEN (KINROOI), 3640 , BE
# ()
#
# WUYTENWEG, 3900 OVERPELT, BE
# ()
#
#
# ()
#
# SERVAASPLEIN, 3590 , BE
# ()
#
# SINT-TRUIDERSTEENWEG, 3840 BORGLOON, BE
# ()
#
#
# ()
#
# LIEPENSWEG 13, 3770 VLIJTINGEN, BE
# ()
#
# BOCHOLTERKIEZEL 17 B, 3960 BREE, BE
# ()
#
# KRUISBOOGSTRAAT, 3920 LOMMEL, BE
# ()
#
#
# ()
#
# MUNTSTRAAT, 3000 LEUVEN, BE
# ()
#
# ERNEST FEYSPLEIN 15 BUS 0802, 8400 OOSTENDE, BE
# ()
#
# VERLOREN KOST 21, 3680 MAASEIK, BE
# ()
#
# KREKELGRACHTSTRAAT 26, 3770 RIEMST, BE
# ()
#
# ERHEMSTRAAT 23, 3770 VLIJTINGEN, BE
# ()
#
# MAASTRICHTERSTRAAT 38, 3770 RIEMST, BE
# ()
#
# POSTHOORNSTRAAT 17/4, 3930 HAMONT-ACHEL, BE
# ()
#
#
# ()
#
#
# ()
#
# RONDESTRAAT 10, 3670 MEEUWEN, BE
# ()
#
#
# ()
#
# WATERLOZEWEG, 3680 NEEROETEREN, BE
# ()
#
#
# ()
#
# TURFSTRAAT, 3690 ZUTENDAAL, BE
# ()
#
# AKKERSTRAAT 49, 3670 MEEUWEN-GRUITRODE, BE
# ()
#
# WOUDDAL 13, 3723 GUIGOVEN, BE
# ()
#
# SOETEBEEK, 3670 WIJSHAGEN, BE
# ()
#
#
# ()
#
# BEVEKOMSESTRAAT 72, 3360 BIERBEEK, BE
# ()
#
# STATIONSSTRAAT, 3840 BORGLOON, BE
# ()
#
# REEKSTRAAT, 3742 BILZEN, BE
# ()
#
# PATER VANWEERTPLEIN 43, 3770 RIEMST, BE
# ()
#
#
# ()
#
# KONINGSSTRAAT, 3900 OVERPELT, BE
# ()
#
# TERWEG 51, 3680 VOORSHOVEN, BE
# ()
#
#
# ()
#
# WATERTORENSTRAAT 39, 3950 KAULILLE, BE
# ()
#
# DOKTER PERGENSLAAN 15., 3680 MAASEIK, BE
# ()
#
# PATER SCHUERMANSSTRAAT, 3990 PEER, BE
# ()
#
# COUSENSTRAAT 13, 3660 , BE
# ()
#
#
# ()
#
# KLAPHOEKSTRAAT, 3730 HOESELT, BE
# ()
#
# STROEKESTRAAT 1A, 3770 VAL-MEER RIEMST, BE
# ()
#
# NECROPOLISSTRAAT 7, 3700 TONGEREN, BE
# ()
#
# BURGEMEESTER MARTINSTRAAT 1, 3620 LANAKEN, BE
# ()
#
#
# ()
#
# PLACE DE L'ÉGLISE 12, 4432 XHENDREMAEL, BE
# ()
#
# MOLENSTRAAT 96, 1570 VOLLEZELE, BE
# ()
#
# HERTSTRAAT 40, 3732 SCHALKHOVEN, BE
# ()
#
# NEERMOLENSTRAAT 16, 3680 NEEROETEREN, BE
# ()
#
# DRIEKRUISENSTRAAT 65, 3700 TONGEREN, BE
# ()
#
# WANDELINGSTRAAT, 8500 KORTRIJK, BE
# ()
#
# PIETER NOLLEKENSSTRAAT 127, 3010 KESSEL-LO, BE
# ()
#
# BOCHOLTERKIEZEL, 3960 BREE, BE
# ()
#
# ZONHOEVESTRAAT, 3740 BILZEN, BE
# ()
#
# BOUDEWIJNSTRAAT 62, TONGEREN, 3700 RUTTEN-TONGEREN, BE
# ()
#
# NECROPOLISSTRAAT 7, 3700 TONGEREN, BE
# ()
#
# ZUTENDAALWEG 70, 3740 BILZEN, BE
# ()
#
# ROBIJNSTRAAT, 3960 BREE, BE
# ()
#
# WEERTERSTEENWEG 144, 3640 KINROOI, BE
# ()
#
# FRAMBOZENSTRAAT 7, 3700 TONGEREN, BE
# ()
#
# VOORSHOVENTERWEG 120 BUS 2, 3680 NEEROETEREN, BE
# ()
#
# HEIKEMP, 3672 MOLENBEERSEL, BE
# ()
#
# ROMERSHOVENSTRAAT 12, 3730 HOESELT, BE
# ()
#
#
# ()
#
# BOOMGAARDSTRAAT 22, 3670 MEEUWEN, BE
# ()
#
# SPURKERWEG, 3740 BILZEN, BE
# ()
#
# SINT ANNADAL 19E, 6214 MAASTRICHT, NL
# ()
#
# NIEUWEWEG54, 3770 RIEMST, BE
# ()
#
# VOIE DE LIÈGE 155, 4053 CHAUDFONTAINE, BE
# ()
#
# PROSPERSTRAAT 2,   (KOTEM), 3631 MAASMECHELEN, BE
# ()
#
# NIELERLOCHSSTRAAT 59, 3680 OPOETEREN, BE
# ()
#
# DE SCHAETZENGAARDE 2, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# TOMMENSTRAAT, 3730 HOESELT, BE
# ()
#
# BALENHOEK, 3930 HAMONT, BE
# ()
#
# SINT-BERTILIASTRAAT 5, 3740 ROSMEER, BE
# ()
#
# DE HASSELS, 53, 2400 MOL, BE
# ()
#
# ERNEST PITONLAAN, 3400 , BE
# ()
#
# KASTEELSTRAAT  2, 3840 HOEPERTINGEN, BE
# ()
#
# GAVERLAND 71, 9620 ZOTTEGEM, BE
# ()
#
#
# ()
#
# WIJNGAARDSTRAAT 165, 3620 LANAKEN, BE
# ()
#
#
# ()
#
# HOVERHOFWEG, 3640 OPHOVEN, BE
# ()
#
# KLEINE KERKSTRAAT, 3680 MAASEIK, BE
# ()
#
# PHILL BOSMANSPLEIN 1, 3670 GRUITRODE, BE
# ()
#
# SACRAMENTSTRAAT 23, 3700 TONGEREN, BE
# ()
#
# BRUULSTRAAT 133, 3360 LOVENJOEL, BE
# ()
#
# PEEERWEG, 3700 VREREN TONGEREN, BE
# ()
#
# SPRINKELESTRAAT 61, 3690 ZUTENDAAL, BE
# ()
#
# ARKSTRAAT 66, 3670 MEEUWEN, BE
# ()
#
# FREDERIK MALDERSSTRAAT 38, 3680 MAASEIK, BE
# ()
#
# WEERAARDSTRAAT 9, 3700 TONGEREN-WIDOOIE, BE
# ()
#
# TERPOORTENLAAN 1, 3730 HOESELT, BE
# ()
#
#
# ()
#
# DE MEANSTRAAT 7B, 3770 RIEMST, BE
# ()
#
# KEVERSSTRAAT 12, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# DE KORTE VOOR 10, 3940 EKSEL, BE
# ()
#
# VERBINDINGSSTRAAT 15, 3680 NEEROETEREN, BE
# ()
#
# GENUTSTRAAT, 3740 BILZEN, BE
# ()
#
# DIKKE HAGESTRAAT 25, 3620 NEERHAREN, BE
# ()
#
# STENENBRUGSTRAAT 11, 3621 REKEM, BE
# ()
#
#
# ()
#
#
# ()
#
#
# ()
#
# SINT TRUIDERSTEENWEG, 3700 TONGEREN, BE
# ()
#
# CUVELIERSTRAAT, 3740 BILZEN, BE
# ()
#
# REPPELERWEG 34, 3950 , BE
# ()
#
# REPPELERWEG 34, 3950 , BE
# ()
#
# TRULSTRAAT, 26, 3730 HOESELT, BE
# ()
#
# WILLEKENSMOLENSTRAAT 229, 3500 , BE
# ()
#
# DRIEVEKKENWEG 14, 3680 NEEROETEREN, BE
# ()
#
# OUDE BAAN, 3665 AS, BE
# ()
#
# VINKENKANTSTRAAT 33, 3660 OPGLABBEEK, BE
# ()
#
# THUIS, 2235 WESTMEERBEEK, BE
# ()
#
# HEIKANT, 3910 NEERPELT, BE
# ()
#
# HOOILINGENSTRAAT, 3730 HOESELT, BE
# ()
#
# RUE DE HERSTAPPE, 4367 ODEUR, BE
# ()
#
# AKKERSTRAAT, 3680 MAASEIK, BE
# ()
#
#
# ()
#
#
# ()
#
# PARADIJSSTRAAT, 9870 ZULTE, BE
# ()
#
# WEG NAAR OPOETEREN 26, 3670 MEEUWEN-GRUITRODE, BE
# ()
#
# HANGVELD 28, 3621 REKEM, BE
# ()
#
# OUDE TRAMWEG 20, 3740 MUNSTERBILZEN, BE
# ()
#
# SPINNEWIELSTRAAT, 28, 3920 LOMMEL, BE
# ()
#
#
# ()
#
# STALKERWEG 13, 3690 ZUTENDAAL, BE
# ()
#
# KANTONNALE BAAN, 3665 AS, BE
# ()
#
# WEG NAAR ZWARTBERG 2, 3660 OPGLABBEEK, BE
# ()
#
# TUINSTRAAT 8, 3950 BOCHOLT, BE
# ()
#
# SCHUTHAAGLAAN, 3740 BILZEN, BE
# ()
#
# UIKHOVERSTRAAT 1A, 3630 UIKHOVEN, BE
# ()
#
# HOUTBLOOKSTRAAT 7, 3600 GENK, BE
# ()
#
#
# ()
#
# RUYTERMARKT 26, 3700 TONGEREN, BE
# ()
#
# SXHEPENENLAAN 5, 3730 HOESELT, BE
# ()
#
# DORPSSTRAAT 75, 3770 RIEMST, BE
# ()
#
# TONGERSESTEENWEG 65, 3730 HOSELT, BE
# ()
#
# GAUUWAKKERSTR, 3621 LANAKEN, BE
# ()
#
# ZEVENBOOMKENSSTRAAT 2 BUS 11, 3570 ALKEN, BE
# ()
#
# DORPSSTRAAT 75, 3770 RIEMST, BE
# ()
#
# GRAANSTRAAT 16, 3930 HAMONT, BE
# ()
#
# TERVELDESTRAAT 13, 3720 KORTESSEM, BE
# ()
#
# WATERTORENSTRAAT 48, 2560 NIJLEN, BE
# ()
#
#
# ()
#
# ROMERSHOVENSTRAAT 22, 3730 HOESELT, BE
# ()
#
# BEEKSTRAAT 73, 3700 TONGEREN, BE
# ()
#
# KRUIDENLAAN 3, 3600 GENK, BE
# ()
#
# BOSPOORT 16, 3680 MAASEIK, BE
# ()
#
# KERKSTRAAT 24, 3870 HEERS-VEULEN, BE
# ()
#
# 26, 3740 BILZEN, BE
# ()
#
# HERTBOSWEG, 3210 LUBBEEK, BE
# ()
#
# ARNOLD SAUWENLAAN, 3650 STOKKEM, BE
# ()
#
# ZANDSTRAAT 36, 3350 WOMMERSOM, BE
# ()
#
# ZEVENBOOMKENSSTRAAT 2 BUS 11, 3570 ALKEN, BE
# ()
#
# ZIELDERVELD 100, 3640 KINROOI, BE
# ()
#
#
# ()
#
#
# ()
#
# E313, 3550 HEUSDEN, BE
# ()
#
#
# ()
#
#
# ()
#
# SOLTERWEG 20, 3680 NEEROETEREN VOORSHOVEN, BE
# ()
#
# HEIRBAAN, 144, 3621 REKEM, BE
# ()
#
# HOLENWEG, 3910 NEERPELT, BE
# ()
#
# HEKSLAAN 111, 3870 HEERS, BE
# ()
#
# WEG NAAR ZWARTBERG 63 BUS 4, 3660 OPGLABBEEK, BE
# ()
#
#
# ()
#
# 44RUE DE LA RÉSISTANCE, 4350 REMICOURT, BE
# ()
#
#
# ()
#
# RIETSTRAAT 3, 3665 AS, BE
# ()
#
#
# ()
#
# KAMPSTRAAT 40, 3621 REKEM, BE
# ()
#
# DE SCHAETZENGAARDE, 3700 TONGEREN, BE
# ()
#
# TONGERSESTEENWEG, 317/, 3840 BORGLOON, BE
# ()
#
# DE SCHAETZENGAARDE, 3700 TONGEREN, BE
# ()
#
# REKEMERSTRAAT, 3621 REKEM -LANAKEN, BE
# ()
#
# IRISSTRAAT, 3600 GENK, BE
# ()
#
#
# ()
#
# MOLDERSHOEVENSTRAAT 99, 3900 OVERPELT, BE
# ()
#
# DORP, 3800 BRUSTEM, BE
# ()
#
# SCHOORBAKKESTRAAT 15, 8600 DIKSMUIDE, BE
# ()
#
#
# ()
#
#
# ()
#
# BLAARSTRAAT, 3700 TONGEREN, BE
# ()
#
# ESCADRON 609, 28, 4300 WAREMME, BE
# ()
#
# KAAISTRAAT 8, 3580 BERINGEN, BE
# ()
#
# OPHEMMERSTRAAT 18, 3770 VLIJTINGEN, BE
# ()
#
# ROZENSTRAAT 4, 3530 HOUTHALEN-OOST, BE
# ()
#
#
# ()
#
# RUE CAMILLE MOÏES 3A, 4280 HANNUT, BE
# ()
#
#
# ()
#
# HOOIPLAATS, 3600 GENK, BE
# ()
#
# DONKSTRAAT 99, 3640 OPHOVEN, BE
# ()
#
# RUE BOUHETTE, 4420 MONTEGNÉE, BE
# ()
#
#
# ()
#
# LOUIS METCIERLAAN 159, 3630 MAASMECHELEN, BE
# ()
#
# BAMPSTRAAT, 3770 RIEMST, BE
# ()
#
# HELSHOVENSTRAAT 27, 3800 SINT-TRUIDEN, BE
# ()
#
# KANAALSTRAAT 12, 3650 ROTEM, BE
# ()
#
#
# ()
#
# HEUVENEINDEWEG 15, 3520 ZONHOVEN, BE
# ()
#
# CHAUSSÉE DE TIRLEMONT 30, 4260 FALLAIS, BE
# ()
#
# RUE DELMETTE 1, 4300 OLEYE, BE
# ()
#
# GIPPERSHOVENSTRAAT 28A, 3800 ZEPPEREN, BE
# ()
#
# SINT-GODFRIEDSTRAAT 17, 3800 SINT-TRUIDEN, BE
# ()
#
# PIJPENHOF 31B BUS 6, 3740 BILZEN, BE
# ()
#
# BLAARSTRAAT 50, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# STRAAT, 3740 MUNSTERBILZEN, BE
# ()
#
# ACHTTIENDE OOGSTWAL 20, 3700 TONGEREN, BE
# ()
#
# SCHEYMANSHOF 32, 3640 KINROOI, BE
# ()
#
# WEG NAAR OPITTER 84, 3670 NEERGLABBEEK, BE
# ()
#
# KERKSTRAAT, 3290 SCHAFFEN, BE
# ()
#
# DOKTER PERGENSLAAN 14, 3680 MAASEIK, BE
# ()
#
#
# ()
#
#
# ()
#
# ROZENSTRAAT 3, 3600 GENK, BE
# ()
#
# VREYSHORRING 36B, 3920 LOMMEL, BE
# ()
#
#
# ()
#
# OP DE KOEL 17, 3665 AS, BE
# ()
#
# MOLENWEG, 368 NEEROETEREN, BE
# ()
#
#
# ()
#
# STALSBOSSTRAAT 12, 3660 OPGLABBEEK, BE
# ()
#
# ROMERSHOVENSTRAAT 113B, 0 3730, BE
# ()
#
# LEGEWEG, 9308 GIJZEGEM, BE
# ()
#
# STRAAT, 3680 DORNE, BE
# ()
#
# RUE RENÉ DETISTE 25, 4280 GRAND HALLET, BE
# ()
#
# MOLENSTRAAT 37, 3960 BREE, BE
# ()
#
# KON.BOUDEWIJNPLEIN 24, 3910 NEERPELT, BE
# ()
#
# SPELTSTRAAT 34, 3650 DILSEN, BE
# ()
#
# A.MEESENLAAN 10, 3700 TONGEREN, BE
# ()
#
# A.MEESENLAAN 10, 3700 TONGEREN, BE
# ()
#
# EINDE 29, 3920 LOMMEL, BE
# ()
#
# KRAAIBORNSTRAAT,63.      LAUW, 3700 TONGEREN LAUW, BE
# ()
#
# GROTE-SPOUWENSTRAAT 17 , 740  BILZEN, 3 , BE
# ()
#
# HOGE AKKER, 2930 BRASSCHAAT, BE
# ()
#
# GRAEVENSTRAAT 13, 3960 BREE, BE
# ()
#
# DEMERSTRAAT 10, 3770 RIEMST MEMBRUGGEN, BE
# ()
#
#
# ()
#
# VOORSHOVENTERWEG 25, 3680 MAASEIK-NEEROETEREN, BE
# ()
#
# M.V.GURPLAAN 66, 3920 LOMMEL, BE
# ()
#
# EGOVENSTRAAT 8, 3800 GELINDEN, BE
# ()
#
# WURFELDERMOLENWEG, 3680 , BE
# ()
#
# MARKT, 17, 3971 HEPPEN, BE
# ()
#
# TICHEL 3, 3910 NEERPELT, BE
# ()
#
#
# ()
#
# TULPENSTRAAT 3, 3770 RIEMST, BE
# ()
#
# SCHANSSTRAAT 36, 3690 ZUTENDAAL, BE
# ()
#
# PANISVELD, 3770 RIEMST, BE
# ()
#
# WEG NAAR AS 31, 3660 OPGLABBEEK, BE
# ()
#
# TOMBENLAAN 1, 3621 REKEM, BE
# ()
#
# PEERDERBAAN, 3969 BREE, BE
# ()
#
# SPARRENHOF, 3290 DIEST, BE
# ()
#
# TOMSTRAAT, 3700 PIRINGEN, BE
# ()
#
# TONGERSESTEENWEG 113, 3730 HOESELT, BE
# ()
#
# DIKKE WEYESTRAAT 2, 3870 HEERS, BE
# ()
#
# WEG NAAR AS 276, 3600 GENK, BE
# ()
#
#
# ()
#
# VAN EYCKLAAN 70, 3680 MAASEIK, BE
# ()
#
# WIJCHMAALSEBAAN 34, 3940 HECHTEL-EKSEL, BE
# ()
#
# BEATRIXSTRAAT 11, 6223 MAASTRICHT, NL
# ()
#
# RUE DE L'O N U, 3, 4260 CIPLET, BE
# ()
#
#
# ()
#
# RIJCKERSTRAAT, 3770 RIEMST, BE
# ()
#
# MEIERSTRAAT, 3640 KINROOI, BE
# ()
#
#
# ()
#
# WILLEM DE ZWIJGERSTRAAT 4A, 6006 WEERT, NL
# ()
#
# KOMVELD 13, 3770 HERDEREN, BE
# ()
#
#
# ()
#
# SINT TRUIDERSTRAAT, 3709 TONGEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# HENSENDRIESWEG 54, 3920 LOMMEL, BE
# ()
#
# HEUKELOMMERWEG, 3770 RIEMST, BE
# ()
#
# LUTTEL 31, 3670 MEEUWEN, BE
# ()
#
# DORPSSTRAAT 55, 3950 BOCHOLT, BE
# ()
#
#
# ()
#
#
# ()
#
# MUNTSTRAAT 1 BUS 1, 3670 MEEUWEN, BE
# ()
#
# STEYVENSTRAAT, 3960 BREE, BE
# ()
#
# VISESTEENWEG 209-1  ZICHEN ZUSSEN BOLDER, 3770 RIEMST, BE
# ()
#
# STIJN STREUVELSLAAN 25, 3730 HOESELT, BE
# ()
#
# HOGERSTRAAT 21 MOLENBEERSEL, 3640 KINROOI, BE
# ()
#
# RAGEVELDSTRAAT, 3746 HOELBEEK, BE
# ()
#
# RUE DE L'O N U, 3, 4260 CIPLET, BE
# ()
#
# BEUKENSTRAAT ,7, 3950 BOCHOLT, BE
# ()
#
# KEIBERG 9, 3700 TONGEREN, BE
# ()
#
# VISÉSTEENWEG, 3770 RIEMST, BE
# ()
#
# TIENDERSTRAAT 91, 3680 MAASEIK, BE
# ()
#
# NIEUWE BAAN 56, 3730 HOESELT, BE
# ()
#
#
# ()
#
# CHAUSSÉE DE MONS 59, 1400 NIVELLES, BE
# ()
#
# TUINSTRAAT, 3950 BOCHOLT, BE
# ()
#
#
# ()
#
# WOUDWEG 7, 3910 NEERPELT, BE
# ()
#
# SPORTLAAN, 3950 BOCHOLT BELGIË, BE
# ()
#
# DORPSTRAAT 17 , ., 3910 NEERPELT, BE
# ()
#
#
# ()
#
# STEENWEG 90 BUS 2, 3665 AS, BE
# ()
#
# KEELHOFFSTRAAT, 3620 NEERHAREN, BE
# ()
#
# ZAVELPUTSTRAAT VELDSTRAAT, 3020 HERENT, BE
# ()
#
# NIEUWSTRAAT, 3600 GENK, BE
# ()
#
# HUVENERSSTRAAT, 3665 AS, BE
# ()
#
# SOLTERBOSSTRAAT, 3680 NEEROETEREN, BE
# ()
#
# BODEMWEG, 3700 TONGEREN, BE
# ()
#
# OUD KERKHOFSTRAAT 24, 3680 MAASEIK, BE
# ()
#
# KASTANJESTRAAT 3, 3670 MEEUWEN (WIJSHAGEN), BE
# ()
#
#
# ()
#
# BARETTESTRAAT 4, 3800 GELINDEN, BE
# ()
#
# BARETTESTRAAT 4, 3800 GELINDEN, BE
# ()
#
# NOORBEEK, LIMBURG, NL, 6255 , NL
# ()
#
# OUDE NEDERBAAN 43, 3730 HOESELT, BE
# ()
#
#
# ()
#
# FREDERIK MALDERSSTRAAT, 3680 MAASEIK, BE
# ()
#
# KROMSTRAAT 16, 3770 RIEMST, BE
# ()
#
# NORBERTINESSENLAAN 6, 3910 NEERPELT, BE
# ()
#
# SCHUTTERIJSTRAAT 7, 3740 BILZEN, BE
# ()
#
# ANDRE DUMONTLAAN 2 BUS 2, 3665 AS, BE
# ()
#
# HILARION THANSLAAN, 3621 REKEM, BE
# ()
#
# LANGSTRAAT 39, 3740 WALTWILDER, BE
# ()
#
#
# ()
#
# EYNDERWEG, 9, 3530 HOUTHALEN-HELCHTEREN, BE
# ()
#
#
# ()
#
# AVENUE DES TRIEUX 10, 5000 NAMUR, BE
# ()
#
# MERELSTRAAT 13, 3660 OPGLABBEEK, BE
# ()
#
# DIRIGENTENHOF 7, 3600 GENK, BE
# ()
#
# OUDE KERKSTRAAT, 3650 DILSEN, BE
# ()
#
#
# ()
#
# VENLOSESTEENWEG 71, 3680 MAASEIK, BE
# ()
#
#
# ()
#
#
# ()
#
# TEUTENSTRAAT, 3930 HAMONT-ACHEL, BE
# ()
#
#
# ()
#
#
# ()
#
# RUE DE PORTO, 4020 LIEGE, BE
# ()
#
# ST-TRUIDERSTEENWEG 417, 3700 PIRINGEN (TONGEREN), BE
# ()
#
#
# ()
#
# PASTOOR GOOSSENSLAAN 117, 3630 UIKHOVEN MAASMECHELEN, BE
# ()
#
#
# ()
#
# CHRISTOF DES GRENADIERS 57, 4690 EBEN EMAEL, BE
# ()
#
# VOSHEUVELSTRAAT, 3950 BOCHOLT, BE
# ()
#
# KEISTRAAT 7, 3740 BILZEN, BE
# ()
#
# GROTE VINNESTRAAT, 3803 DURAS, BE
# ()
#
# KAPELWEG 34, 3680 MAASEIK, BE
# ()
#
# VISÉSTEENWEG, 3770 RIEMST, BE
# ()
#
# RIBUSSTRAAT 9, 3740 BILZEN, BE
# ()
#
# RUE HAUTE VOIE 35, 4690 WONCK, BE
# ()
#
# PAALSTEENLAAN 58, 3620 LANAKEN, BE
# ()
#
# NIEUWE STEENWEG, 3870 HEERS, BE
# ()
#
#
# ()
#
# SMISVELD 11, 3832 ULBEEK, BE
# ()
#
# RUE DES ÉCOLES, 14, 4540 AMAY, BE
# ()
#
# STEYVENSTRAAT, 3960 BREE, BE
# ()
#
# NIELERSTRAAT 11, 3680 DORNE,MAASEIK, BE
# ()
#
# MAGERSTRAAT 47B, 8501 HEULE, BE
# ()
#
# CUVELIERSTRAAT 13A, 3740 BILZEN RIJKHOVEN, BE
# ()
#
# EUROPALAAN, 3650 DILSEN, BE
# ()
#
# GRAVIERSTRAAT 90, 3700 TONGEREN, BE
# ()
#
# MOUHIN, 4300 WAREMME, BE
# ()
#
# HAVIKSTRAAT 19, 2590 BERLAAR, BE
# ()
#
# BURGEMEESTER DELWAIDELAAN 12, 3621 REKEM, BE
# ()
#
# RUE DE LA BELLE VUE, 4250 BOËLHE, BE
# ()
#
#
# ()
#
# VISÉSTEENWEG, 3770 RIEMST, BE
# ()
#
#
# ()
#
# MAASTRICHTERSTRAAT 14, 3740 BILZEN, BE
# ()
#
# WIJKSTRAAT 27, 3590 DIEPENBEEK, BE
# ()
#
# SINT-GEERTRUISTRAAT 70, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# KERNIELERWEG, 3840 BORGLOON, BE
# ()
#
# MOLENSTRAAT, 3730 HOESELT, BE
# ()
#
#
# ()
#
# WINHOFSTRAAT, 3700 TONGEREN, BE
# ()
#
# HAGERWEG 22, 3680 MAASEIK, BE
# ()
#
# PLEIN 112, 3212 PELLENBERG, BE
# ()
#
# GOOSWEG, 3950 KAULILLE, BE
# ()
#
#
# ()
#
# BENTSTRAAT 60, 3590 DIEPENBEEK, BE
# ()
#
# ACHTTIENDE OOGSTWAL 20 BUS 25, 3700 TONGEREN, BE
# ()
#
# VERBINDINGSWEG, 3940 HECHTEL, BE
# ()
#
# GROENSTRAAT 30, 3723 GUIGOVEN, BE
# ()
#
#
# ()
#
# STATIONSSTRAAT 129 B3, 3665 AS, BE
# ()
#
# MOERENSTRAAT 10, 3700 TONGEREN, BE
# ()
#
# PASTOOR GOOSSENSLAAN, 3631 UIKHOVEN, BE
# ()
#
#
# ()
#
# HENISSTRAAT, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# SINT-GEERTRUISTRAAT, 3700 TONGEREN, BE
# ()
#
# RIEMSTERWEG, 3740 BILZEN (KLEINE-SPOUWEN), BE
# ()
#
# RUE NESTOR ROYER, 10, 4367 CRISNÉE, BE
# ()
#
# GAARVELDSTRAAT, 3500 HASSELT, BE
# ()
#
#
# ()
#
# RUE XHAVEE, 1, 4460 GRACE-HOLLOGNE, BE
# ()
#
# GESTELSTRAAT 18, 3670 MEEUWEN, BE
# ()
#
# NIEUWSTRAAT 27, 3665 AS, BE
# ()
#
# GESTELSTRAAT 18, 3670 MEEUWEN, BE
# ()
#
# KINROOIERSTEENWEG 53, 3680 NEEROETEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# GROTE STRAAT 101, 3770 VAL-MEER, BE
# ()
#
#
# ()
#
# OVERREPENSTRAAT, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# TEN HOVE 20, 3510 KERMT, BE
# ()
#
# BLAARSTRAAT 102, 3700 TONGEREN, BE
# ()
#
# OVERREPENSTRAAT 29, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# OSCAR LELARGE, 4520 WANZE, BE
# ()
#
#
# ()
#
#
# ()
#
# KERSELARENSTRAAT, 3700 VREREN, BE
# ()
#
# RUE LOUIS HAPPART 38, 4367 CRISNÉE, BE
# ()
#
# PASTOOR GOOSSENSLAAN 150, 3631 UIKHOVEN, BE
# ()
#
# EKSTERVELDWEG 10, 3650 DILSEN-STOKKEM, BE
# ()
#
# DALSTRAAT 6, 3660 OPGLABBEEK, BE
# ()
#
# OLMENWEG 24, 3970 BOURG-LÉOPOLD, BE
# ()
#
# KLEIN-LAFELTSTRAAT 15, 3770 RIEMST, BE
# ()
#
# BEEMDSTRAAT 8, 3700 TONGEREN, BE
# ()
#
# TER VOORT 29, 2260 WESTERLO, BE
# ()
#
# BERKENLAAN 39, 3680 MAASEIK, BE
# ()
#
# LANGBAMDWEG 7, 3700 TONGEREN, BE
# ()
#
# PASBRUGSTRAAT TE, 3730 HOESELT, BE
# ()
#
# PASTOORSLINDESTRAAT, 3620 LANAKEN, BE
# ()
#
# SCHUILSTRAAT, 4, 3630 MAASMECHELEN, BE
# ()
#
# KLOOSTERWAL 3, 3740 BILZEN, BE
# ()
#
#
# ()
#
#
# ()
#
# NORBERTINESSENLAAN 6, 3910 NEERPELT, BE
# ()
#
# PEERDERBAAN, 3960 BREE, BE
# ()
#
# EUROPAWIJK 66,  EKSEL, 3940 HECHTEL-EKSEL, BE
# ()
#
# SPARRENLAAN, 3730 HOESELT, BE
# ()
#
# SMEETSHOFWEG, 3990 PEER, BE
# ()
#
# PRIESTER DAENSSTRAAT 22, 3010 KESSEL-LO, BE
# ()
#
# WEERSTANDERSSTRAAT 23, 3870 HEERS, BE
# ()
#
# KAKEBEEKSTRAAT 9, 3950 BOCHOLT, BE
# ()
#
# SINT-ANTONIUSSTRAAT 11, 3700 TONGEREN, BE
# ()
#
# WEG NAAR AS 113, 3680 DORNE-MAASEIK, BE
# ()
#
#
# ()
#
# LINDERSTRAAT 116, 3700 TONGEREN, BE
# ()
#
# OPHEMMERSTRAAT 61, 3770 VLIJTINGEN, BE
# ()
#
# HERENVELDSTRAAT 3, 3730 HOESELT, BE
# ()
#
# SINT-JOZEFSSTRAAT 3, 3550 HEUSDEN-ZOLDER, BE
# ()
#
# STANISLAS FLEUSSU 15A, 4300 WAREMME, BE
# ()
#
#
# ()
#
#
# ()
#
# RUE DE BIERSET, 4300 BOVENISTIER, BE
# ()
#
# OVERREPEN STRAAT, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# EUROPAPLEIN 26 BUS 4, 3630 MAASMECHELEN, BE
# ()
#
# ELCKERLYCSTRAAT 8, 3670 NEERGLABBEEK, BE
# ()
#
# MAASTRICHTERSTEENWEG 141 TONGEREN, 3700 TONGEREN (BELGIÊ), BE
# ()
#
#
# ()
#
# DRIEVEKKENWEG 70, 3680 NEEROETEREN, BE
# ()
#
# GROENSTRAAT, 3660 OPGLABBEEK, BE
# ()
#
# MAASTRICHTERSTRAAT, 3700 TONGEREN, BE
# ()
#
# REDEMPTIESTRAAT 2 BUS 1, 3740 MOPERTINGEN, BE
# ()
#
# MILLENSTRAAT 47, 3960 BREE, BE
# ()
#
# GRAEVENSTRAAT 12, 3960 BREE, BE
# ()
#
# QUAI DES ARDENNES 198, 4032 , BE
# ()
#
# SINT-ALDEGONDISSTRAAT, 3740 BILZEN, BE
# ()
#
# BURG. MARTINSTRAAT, 3620 LANAKEN, BE
# ()
#
# RUITERSSTRAAT 1, 3560 LUMMEN, BE
# ()
#
# OUDE OPHOVERBAAN, 3680 MAASEIK, BE
# ()
#
# TROFFELSTRAAT, 3740 BILZEN, BE
# ()
#
# WINTERSTRAAT 53, 3740 BILZEN, BE
# ()
#
# BOOGSTRAAT 34, 3600 GENK, BE
# ()
#
#
# ()
#
# VELDSTRAAT 5, 3621 LANAKEN, BE
# ()
#
#
# ()
#
# HEURSTRAAT, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# KLINKSTRAAT, 3570 ALKEN, BE
# ()
#
#
# ()
#
# MORTELVELDSTRAAT., 3650 ELEN, BE
# ()
#
# FONTEINSTRAAT 9, 3950 BOCHOLT, BE
# ()
#
# PRUIMELARENSTRAAT 29, 3700 TONGEREN, BE
# ()
#
# AVENUE MOZART 59, 1190 FOREST (BRUXELLES), BE
# ()
#
#
# ()
#
# , BESSEMERSTRAAT 46, 3620 LANAKEN, BE
# ()
#
# VOORTSTRAAT, 3560 LUMMEN, BE
# ()
#
# BOTERMARKT, 3650 STOKKEM, BE
# ()
#
#
# ()
#
# KORENBLOEMSTRAAT  10, 3700 TONGEREN, BE
# ()
#
# STEENVELTSTRAAT 20, 1180 UKKEL, BE
# ()
#
# TONGERSESTEENWEG 60, 3730 HOESELT, BE
# ()
#
# DOORNKAPPERSPLEIN 4, 3730 HOESELT, BE
# ()
#
# VENSTRAAT, 3700 VREREN, BE
# ()
#
#
# ()
#
# BOLDERSTRAAT 70., 3770 ZICHEN-ZUSSEN-BOLDER, BE
# ()
#
# KLEINE KOUTER 47, 3400 NEERWINDEN, BE
# ()
#
# PRINSENHOFLAAN 20, 3680 MAASEIK, BE
# ()
#
# TWEEDE STRAAT 39, 3680 MAASEIK, BE
# ()
#
# LANGSTRAAT, 3740 WALTWILDER, BE
# ()
#
# THERESIASTRAAT 28/4, 3500 HASSELT, BE
# ()
#
# ZONHOVERWEG 101, 3600 GENK, BE
# ()
#
# LEOPOLD III-STRAAT 63A, 3724 , BE
# ()
#
# HANEKAPSTRAAT 6, 3920 LOMMEL, BE
# ()
#
# WEERTERSTEENWEG 60, 3680 MAASEIK, BE
# ()
#
# RUE DE BORSET, 4537 CHAPON-SERAING, BE
# ()
#
# ENGSBERGSEWEG 218, 3980 TESSENDERLO, BE
# ()
#
# GENUTSTRAAT 8, 3740 BILZEN, BE
# ()
#
#
# ()
#
# LEEMKUILSTRAAT 75A, 3570 ALKEN, BE
# ()
#
# BREMSTRAAT 49, 3620 LANAKEN, BE
# ()
#
# KONINKSEMSTRAAT, TONGEREN-KONINKSEM, 3700 , BE
# ()
#
# SINT-PIETERSGROENESTRAAT 34, 8000 BRUGGE, BE
# ()
#
#
# ()
#
# OPHOVENSTRAAT 170,  GUITRODE, 3670 GRUITRODE, BE
# ()
#
# KOUNTERSTRAAT 71, 3620 LANAKEN, BE
# ()
#
# SALVATORSTRAAT 51, 3930 HAMONT-ACHEL, BE
# ()
#
#
# ()
#
#
# ()
#
# DONKERSTRAAT 28, 3870 HEERS (HORPMAAL), BE
# ()
#
# BOOMGAARDSTRAAT, 3730 HOESELT, BE
# ()
#
# HASSELTSESTEENWEG 178, 3700 TONGEREN, BE
# ()
#
# BOVENSTRAAT 56, 3550 HEUSDEN-ZOLDER, BE
# ()
#
# VETTERSSTRAAT 40, 3511 KURINGEN, BE
# ()
#
# DIESTERSESTEENWEG 15, 3583 PAAL, BE
# ()
#
# STATIONSSTRAAT 12, 2830 WILLEBROEK, BE
# ()
#
# HAMEISTRAAT 5, 3800 BRUSTEM, BE
# ()
#
#
# ()
#
# T HASSELTKIEZEL 9, 3960 BREE, BE
# ()
#
# SINT-ALBANUSSTRAAT 86, 3770 RIEMST, BE
# ()
#
# KEMPENSTRAAT 11, 3700 TONGEREN, BE
# ()
#
# ASDONCKSTRAAT, 3971 HEPPEN, BE
# ()
#
# VENLOSESTEENWEG 122, 3640 KINROOI, BE
# ()
#
# BROEKSTRAAT 27A, 3640 KINROOI, BE
# ()
#
# PLANTAGE 33, 3680 MAASEIK, BE
# ()
#
#
# ()
#
# KONINGIN ASTRIDLAAN 34, 3680 MAASEIK, BE
# ()
#
# DE CRENWICK 7, 4250 BOËLHE, BE
# ()
#
# TIENDERSTRAAT, 3680 NEEROETEREN, BE
# ()
#
# OUD KEVELAER, 3640 MOLENBEERDEL, BE
# ()
#
# BOEKHOUTSTRAAT 23 A, 3890 GINGELOM, BE
# ()
#
# KRUISSTRAAT, 3730 HOESELT, BE
# ()
#
# KAPELSTRAAT 122, 3650 DILSEN-STOKKEM, BE
# ()
#
# HEIRSTRAAT 205, 3630 MAASMECHELEN, BE
# ()
#
# GROTESTRAAT 51, 3540 HERK-DE-STAD, BE
# ()
#
# RUE DES COMBATTANTS 17, 4280 HANNUT, BE
# ()
#
# LOERSTRAAT 26, 3680 MAASEIK, BE
# ()
#
# APPELVELDSTRAAT, 3740 BEVERST, BE
# ()
#
# ELVENSCHANS 8, 3790 MOULAND, BE
# ()
#
#
# ()
#
# OUD KEVELAER, 3640 KINROOI, BE
# ()
#
# SCHEYERVELD 1A, 3640 KINROOI, BE
# ()
#
#
# ()
#
#
# ()
# MAASEIKERBAAN, 3960 OPITTER, BE
# ()
#
# MAASTRICHTERSTEENWEG 89, 3680 MAASEIK, BE
# ()
#
# VLASVENSTRAAT 8, 3640 MOLENBEERSEL, BE
# ()
#
# TONGERSESTEENWEG 114, 3730 HOESELT, BE
# ()
#
# KLOKKEHOFSTRAAT 21, 3720 KORTESSEM, BE
# ()
#
# HERDERENWEG 8, 3740 BILZEN, BE
# ()
#
#
# ()
#
# PIETERBREUGHELSTRAAT 8, 3680 MAASEIK, BE
# ()
#
# MOLENWEG 77, 3770 RIEMST VLIJTINGEN, BE
# ()
#
# KRUISSTRAAT 29, 3730 HOESELT, BE
# ()
#
# RUE DU COUCOU, 6010 CHARLEROI, BE
# ()
#
# SEPULKRIJNENLAAN 57, 3500 HASSELT, BE
# ()
#
# RUE DE BOVENISTIER 59, 4350 REMICOURT, BE
# ()
#
# CHAUSSÉE DE TONGRES 588, 4452 JUPRELLE, BE
# ()
#
# RUE DE HUY,170, 4317 VIEMME, BE
# ()
#
# GEENSSTRAAT 45, 3660 OPGLABBEEK, BE
# ()
#
#
# ()
#
# LEOPOLDLAAN 120, 3900 OVERPELT, BE
# ()
#
# BOSSTRAAT 47  HAMONT, 3930 HAMONT-ACHEL, BE
# ()
#
# WATERLOZEWEG, 3680 NEEROETEREN, BE
# ()
#
# HERESTRAAT, 3721 VLIERMAALROOT, BE
# ()
#
# RUE LOUIS MARECHAL 37, 4360 OREYE, BE
# ()
#
#
# ()
#
# AVENUE ROGER DE GRIMBERGHE 6, 1330 RIXENSART, BE
# ()
#
# ST ALDEGONDISSTRAAT 19, 3740 KL SPOUWEN BILZEN, BE
# ()
#
# NEREMWEG 80, 3700 TONGEREN, BE
# ()
#
# MERESTRAAT, 3770 RIEMST, BE
# ()
#
# WEG NAAR ZWARTBERG 115 - HOUTHALEN, 3530 HOUTHALEN -OOST, BE
# ()
#
# OLMSTRAAT, 8790 WAREGEM, BE
# ()
#
#
# ()
#
#
# ()
#
# WEG OP BREE 27/6, 3670 MEEUWEN, BE
# ()
#
# WILGENWEG 10, 3950 BOCHOLT, BE
# ()
#
# MODELSTAD 10, 3650 DILSEN-STOKKEM, BE
# ()
#
# NEDERSTRAAT 23C, 3730 HOESELT, BE
# ()
#
# KRAAIBOSSTRAAT, 8552 MOEN, BE
# ()
#
# LETERWEG 14, 3740 BILZEN, BE
# ()
#
#
# ()
#
# KERKSTRAAT 9, 3640 KINROOI, BE
# ()
#
# RUELLE DES LOUPS, 4690 EBEN EMAEL, BE
# ()
#
# HEUVELSTRAAT 91, 3130 BETEKOM, BE
# ()
#
# BERGEROTHWEG, 6039 STRAMPROY, NL
# ()
#
# OOST, 3530 HOUTHALEN, BE
# ()
#
# BOSSTRAAT 11, 3770 VLIJTINGEN, BE
# ()
#
# RODE KRUISLAAN 14, 3700 TONGEREN, BE
# ()
#
# RUE DE LEGLISE DE SART,, 1490 COURT-SAINT-ETIENNE, BE
# ()
#
# RUE DE LEGLISE DE SART,, 1490 COURT-SAINT-ETIENNE, BE
# ()
#
# VROENTESTRAAT, 3320 HOEGAARDEN, BE
# ()
#
# SPEELBOSWEG 12, 3740 BILZEN, BE
# ()
#
# WEG NAAR ZWARTBERG 409, 3660 OPGLABBEEK, BE
# ()
#
#
# ()
#
# GROENSTRAAT, 3621 LANAKEN-REKEM, BE
# ()
#
# ARMAND MEESENLAAN, 3700 TONGEREN, BE
# ()
#
# CHAUSSÉE DE VLEURGAT 39, 1050 BRUXELLES, BE
# ()
#
# SCHOORSTRAAT 20,  UIKHOVEN, 3631 UIKHOVEN, MAASMECHELEN, BE
# ()
#
# POPULIERENSTRAAT, 3730 HOESELT, BE
# ()
#
# RIJKSWEG 127, 3650 DILSEN, BE
# ()
#
# KLEINESTRAAT14, 3640 MOLENBEERSEL, BE
# ()
#
#
# ()
#
# AMBIORIXSTRAAT 33, 3700 TONGEREN, BE
# ()
#
# TONGERSESTRAAT 65/31, 3740 BILZEN, BE
# ()
#
# DE LOCHT 14, 3700 TONGEREN, BE
# ()
#
# RIJKSWEG 237 BUS3, 3650 DILSEN STOKKEM, BE
# ()
#
# OPHOVENSTRAAT 115/11, 3680 NEEROETEREN, BE
# ()
#
#
# ()
#
# MOMBERSTRAAT 2 BUS 4, 3700 TONGEREN, BE
# ()
#
# EERSTE MESISTRAAT 30, 3700 TONGEREN, BE
# ()
#
# ELFDZN NOVEMBERWAL 26, 3700 TONGEREN, BE
# ()
#
# SINT ROCHUSSTRAAT 3  ZICHEN ZUSSEN BOLDER, 3770 RIEMST, BE
# ()
#
# MEERHEIDEWEG 5, 2980 ZOERSEL, BE
# ()
#
# HAAGWEG 3, 3670 NEERGLABBEEK, BE
# ()
#
# RUE REINE ASTRID, 4260 , BE
# ()
#
# LINDERSTRAAT 139, 3700 TONGEREN, BE
# ()
#
# SINT MAARTENSSTRAAT, 3742 MARTENSLINDE, BE
# ()
#
# KORENSTRAAT 7, 3600 GENK, BE
# ()
#
# DRIESSTRAAT, 3800 ZEPPEREN, BE
# ()
#
#
# ()
#
# BESSEMERSTRAAT, 3620 LANAKEN, BE
# ()
#
#
# ()
#
# HUGO VAN DER GOESSTRAAT 1 BUS 6, 3680 MAASEIK, BE
# ()
#
# BERKENLAAN 13, 3680 MAASEIK, BE
# ()
#
# BOCHOLTERKIEZEL, 3960 BREE, BE
# ()
#
# BOLDERSTRAAT 164 VAL-MEER, 3770 RIEMST, BE
# ()
#
# WINTERSTRAAT 83, 3740 BILZEN, BE
# ()
#
# CATSBEEKSTRAAT 19, 3730 HOESELT, BE
# ()
#
# AMBIORIXSTRAAT 23, 3700 TONGEREN, BE
# ()
#
# ROMEINSE KASSEI 252, 3700 KONINKSEM, BE
# ()
#
# HAMONTERWEG 219, 3950 BOCHOLT, BE
# ()
#
# EERSTE STRAAT 26, 3680 MAASEIK, BE
# ()
#
# EERSTE STRAAT 26, 3680 MAASEIK, BE
# ()
#
# EERSTE STRAAT 26, 3680 MAASEIK, BE
# ()
#
# MEMBRUGGERWEG 33, 3700 TONGEREN, BE
# ()
#
# AADIJK 27, 5575 LUYKSGESTEL, NL
# ()
#
# DIRIKENLAAN 6, 3700 TONGEREN, BE
# ()
#
# KIPDORPSTRAAT, 3960 BREE, BE
# ()
#
# GREVENBROEKSTRAAT 27, 3930 ACHEL, BE
# ()
#
#
# ()
#
# BREMSTRAAT 4, 3690 ZUTENDAAL, BE
# ()
#
# TREKSCHURENSTRAAT 87, 3500 HASSELT, BE
# ()
#
# BREEERWEG 9, 3680 NEEROETEREN, BE
# ()
#
# VELDSTRAAT 2, 3621 REKEM-LANAKEN, BE
# ()
#
# HORPMAALSTRAAT, 3870 HEERS, BE
# ()
#
# IERS-KRUISSTRAAT 124, 3770 RIEMST, BE
# ()
#
# VISEWEG 40E, 3700 SLUIZEN, BE
# ()
#
#
# ()
#
#
# ()
#
# CATSBEEKSTRAAT 7, 3730 HOESELT, BE
# ()
#
#
# ()
#
#
# ()
#
# VRIJHEERSSTRAAT 77, 3800 SINT-TRUIDEN, BE
# ()
#
# POTGIETERSTRAAT 16 (VERDIEP 3) -, 2060 ANTWERPEN, BE
# ()
#
# BURG 35 BUS 2, 3930 HAMONT, BE
# ()
#
#
# ()
#
# VISEWEG, 3700 TONGEREN, BE
# ()
#
# VERGELSWEG 14, 3680 MAASEIK, BE
# ()
#
# TONGERSESTEENWEG 11, 3840 BORGLOON, BE
# ()
#
# SINT-TRUIDERSTEENWEG 193, 3700 TONGEREN, BE
# ()
#
# ROEXEINDESTRAAT, 3660 OPGLABBEEK (OUDSBERGEN), BE
# ()
#
#
# ()
#
# BUVINGENSTRAAT, NIEL-BIJ-ST.-TRUIDEN, 3890 GINGELOM, BE
# ()
#
#
# ()
#
# STATIONSSTRAAT, 3665 AS, BE
# ()
#
# LANGESTRAAT 44, 8570 ANZEGEM, BE
# ()
#
# MERESTRAAT 18, 3770 RIEMST, BE
# ()
#
# MOLENWEG, 3660 OPGLABBEEK, BE
# ()
#
# STRAAT, 3740 HEES, BE
# ()
#
# BREENDONSTRAAT 30, 3800 SINT-TRUIDEN, BE
# ()
#
#
# ()
#
# BURGEMEESTERSSTRAAT 54, 3870 HEERS, BE
# ()
#
# HILVENHOF 26, 3640 KINROOI, BE
# ()
#
# CENTERPARKS, 3920 LOMMEL, BE
# ()
#
# HOOGSTRAAT, 3730 HOESELT, BE
# ()
#
# KANTONNIERSTRAAT  18 BUS 3, 3670 MEEUWEN, BE
# ()
#
# RUE DE THYS 35, 4360 OREYE, BE
# ()
#
# RIJCKERSTRAAT 94, 3770 RIEMST, BE
# ()
#
#
# ()
#
# VENLOSESTEENWEG 71, 3680 MAASEIK, BE
# ()
#
# TONGERSESTEENWEG 360B, 3724 KORTESSEM, BE
# ()
#
# KIEWITSTRAAT 27, 3500 HASSELT, BE
# ()
#
# . IN BED, 3950 BOCHOLT, BE
# ()
#
#
# ()
#
# BLOEMENSTRAAT 23/3, 3500 HASSELT, BE
# ()
#
# LUIKERSTEENWEG 160B, 3700 TONGEREN, BE
# ()
#
# MAASTRICHTERSRAAT 14, 3740 BILZEN, BE
# ()
#
# WINTERSTRAAT 2, 3740 BILZEN, BE
# ()
#
# VOIE DU JOINTY,5, 4537 , BE
# ()
#
# DIESTERSTRAAT, 3980 TESSENDERLO, BE
# ()
#
# PIETER GEUNSSTRAAT 19, 3680 MAASEIK, BE
# ()
#
# KERKHENIS 56, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# RUE DU HUSQUET, 60, 4820 DISON, BE
# ()
#
# WIELEWAALSTRAAT, 3700 TONGRES, BE
# ()
#
# MANDENSTRAAT 1, 3650 DILSEN-STOKKEM, BE
# ()
#
# BOSSTRAAT 65, 3680 MAASEIK, BE
# ()
#
# ST PIETERSSTRAAT 50, 3630 LEUT-MAASMECHELEN, BE
# ()
#
# STOPSTRAAT, 3770 RIEMST, BE
# ()
#
# KAPELWEG, 3680 MAASEIK, BE
# ()
#
#
# ()
#
# SPILSTRAAT 76, 3680 NEEROETEREN, BE
# ()
#
# BROEKSBEEMDENSTRAAT 1  MEEUWEN-GRUITRODE, 3670 WIJSHAGEN, BE
# ()
#
# KLOOSTERSTRAAT 1, 3770 RIEMST, BE
# ()
#
#
# ()
#
# POEL, 9450 DENDERHOUTEM, BE
# ()
#
#
# ()
#
# RUE DE WAREMME, 4257 BERLOZ, BE
# ()
#
# SCHAMPROOD 154, 3920 LOMMEL, BE
# ()
#
# KANAALSTRAAT, 3920 LOMMEL, BE
# ()
#
# NACHTEGAALSTRAAT 88, 3910 NEERPELT, BE
# ()
#
# SINT-JANSSTRAAT, 3730 ROMERSHOVEN, BE
# ()
#
# LAAKSTRAAT 13  BILZEN, 3740 BILZRN, BE
# ()
#
# SCHEYMANSHOF 13, 3640 KINROOI, BE
# ()
#
#
# ()
#
# NIELERSTRAAT, 3680 OPOETEREN DORNE, BE
# ()
#
# DORPSSTRAAT 8, 3720 KORTESSEM, BE
# ()
#
# GROOTROOTSTRAAT 79, 3680 NEEROETEREN, BE
# ()
#
# VOIE DU JOINTY,5, 4537 VERLAINE, BE
# ()
#
# SPEELTUINSTRAAT 21A, 3660 OPGLABBEEK, BE
# ()
#
# VALERIAANSTRAAT 13, 3512 STEVOORT, BE
# ()
#
# HEIDESTRAAT, 16 BUS 6, 3660 OPGLABBEEK, BE
# ()
#
#
# ()
#
# DIESTERSTEENWEG 309, 3680 MAASEIK, BE
# ()
#
# BLAARSTRAAT 82, 3700 TONGEREN, BE
# ()
#
# HERENT 26, 3910 NEERPELT, BE
# ()
#
# VLOETERSTRAAT 19., 3900 OVERPELT, BE
# ()
#
#
# ()
#
# HEIRBAAN 95, 3620 LANAKEN, BE
# ()
#
# GROENSTRAAT 70, 3960 BREE TONGERLO, BE
# ()
#
# VIA JULIANUS 4, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# GROENSTRAAT 39, 3700 TONGEREN, BE
# ()
#
# BERKESTRAAT 12, 3950 BOCHOLT, BE
# ()
#
# STATIONSSTRAAT 85, 3665 AS, BE
# ()
#
# RONDESTRAAT, 3950 BOCHOLT, BE
# ()
#
# JACHTHOORNLAAN, 2970 'S GRAVENWEZEL, BE
# ()
#
# GROTLAAN 7, 3680 NEEROETEREN, BE
# ()
#
# WATERSTRAAT, 3620 LANAKEN, BE
# ()
#
# UILSTRAAT 10, 3470 KORTENAKEN, BE
# ()
#
# ZONHOEVESTRAAT, 3740 BEVERST, BE
# ()
#
# KANAALKOM 4 B, 3960 BREE, BE
# ()
#
# KANAALSTRAAT 52, 3680 NEEROETEREN, BE
# ()
#
# VIJF KRUISENSTRAAT 22,  VAL-MEER, 3770 RIEMST, BE
# ()
#
#
# ()
#
#
# ()
#
# RUE SAINT PIERRE, 4690 GLONS, BE
# ()
#
# KABERGHEIDESTR 48, 3590 DIEPENBEEK, BE
# ()
#
# ZANDSTRAAT, 3665 AS, BE
# ()
#
# ELSAKKER 20, 3950 KAULILLE, BE
# ()
#
# TEUNESTRAAT  62, 3640 KINROOI, BE
# ()
#
# EVIESTRAAT, 3600 GENK, BE
# ()
#
# GRUITRODERBAAN 62, 3670 MEEUWEN, BE
# ()
#
# HENSEMSTRAAT, 3670 MEEUWEN, BE
# ()
#
# BOUDEWIJNSTRAAT 60, 3700 RUTTEN, BE
# ()
#
#
# ()
#
# ST-ALBANUSSTRAAT 86, 3770 VLIJTINGEN, BE
# ()
#
#
# ()
#
# BINNENLAAN 96, 3600 GENK, BE
# ()
#
#
# ()
#
# MANGELBEEKSTRAAT 44, 3560 LUMMEN, BE
# ()
#
# NEEREINDE 4, 3665 , BE
# ()
#
#
# ()
#
# PROVINCIALE 718, 4450 SLINS, BE
# ()
#
# VALMEERSTRAAT 99, 3770 RIEMST, BE
# ()
#
# DIESTERSTEENWEG 45Z, 3680 MAASEIK, BE
# ()
#
# WATERSTRAAT 123, 2940 STABROEK, BE
# ()
#
# BILZERSTEENWEG, 3730 HOESELT, BE
# ()
#
# SYLVAIN PANIS 22, 4367 CRISNEE, BE
# ()
#
# HOOGBLOOKSTRAAT, 26, 3590 DIEPENBEEK, BE
# ()
#
# MOLENSTRAAT 40, 3950 KAULILLE, BE
# ()
#
#
# ()
#
# KORTESTRAAT 3, 3990 GROTE BROGEL, BE
# ()
#
# KLEINE HULST, 3630 MAASMECHELEN, BE
# ()
#
# SOUWVELD 13, 3740 BILZEN, BE
# ()
#
# RUE BLANDOT 18, 4130 TILFF, BE
# ()
#
#
# ()
#
# DARENBERGSTRAAT, 3700 TONGEREN, BE
# ()
#
# MANTELSTRAAT 16, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# STIJN-STREUVELSLAAN 5, 3730 HOESELT, BE
# ()
#
# SERINGENLAAN, 3990 PEER, BE
# ()
#
# TRAMSTRAAT 51, 3800 SINT-TRUIDEN, BE
# ()
#
# LOUIS HAPPART, 4367 CRISNEE, BE
# ()
#
# ROMEINSESTRAAT 2 -, 3740 WALTWILDER, BE
# ()
#
# PRUIMENSTRAAT, 3800 SINT-TRUIDEN, BE
# ()
#
# RUE DE LA CITÉ 21, 4360 OREYE, BE
# ()
#
# NEERMOLENWEG, MEEUWEN, 3670 MEEUWEN-ELLIKOM, BE
# ()
#
# DE TIECKENSTRAAT 26, 3840 BORGLOON, BE
# ()
#
# HANGVELD, 3621 LANAKEN, BE
# ()
#
#
# ()
#
# AVENUE DES COMBATTANTS, 16 -, 1332 GENVAL, BE
# ()
#
# SCHOTERHEIDE 10, 3980 TESSENDERLO, BE
# ()
#
# FRANKENHOF 3, 3621 REKEM, BE
# ()
#
#
# ()
#
#
# ()
#
# ELDERSBROEK 5, 3700 TONGEREN, BE
# ()
#
# SAPSTRAAT 21, 3740 GROTE SPOUWEN BILZEN, BE
# ()
#
# OUDE HEIDESTRAAT, 21, 3740 BILZEN, BE
# ()
#
# FABRIEKSTRAAT 28, 3910 NEERPELT, BE
# ()
#
# BRANDHOUTSTRAAT 14 (BRUSTEM-), 3800 SINT-TRUIDEN, BE
# ()
#
# OP DE KALENBERG, 3590 DIEPENBEEK, BE
# ()
#
# PLACE ROI ALBERT 5, 4690 BASSENGE, BE
# ()
#
# DRIEBEKENWEG, 3680 MAASEIK, BE
# ()
#
# BIESTERTSTRAAT, 3740 GROTE-SPOUWEN, BE
# ()
#
# MAKKESTRAAT, 3640 KINROOI, BE
# ()
#
#
# ()
#
# -DORP 58, 3800 ORDINGEN, BE
# ()
#
# WIJNGAARDSTRAAT, 3740 MUNSTERBILZEN, BE
# ()
#
# MULK, 3930 HAMONT, BE
# ()
#
# ELSTERWEG 19, 3770 RIEMST, BE
# ()
#
# RUE DE MONTIGNY, 5300 VEZIN, BE
# ()
#
#
# ()
#
# GIELENSTRAAT 8, 3770 RIEMST ZICHEN Z.B., BE
# ()
#
# BERGWEIDESTRAAT 1, 3730 HOESELT, BE
# ()
#
#
# ()
#
# BEEMDSTRAAT 32, 3670 MEEUWEN, BE
# ()
#
# WIEËRSWEG 65 TE  NEEROETEREN, 3680 MAASEIK, BE
# ()
#
# DAMBURGSTRAAT 78, 3950 BOCHOLT, BE
# ()
#
#
# ()
#
# STREET #26#, 3454 , BE
# ()
#
#
# ()
#
# RUE DE LA PLACE, 1350 JAUCHE, BE
# ()
#
# ASSERWEG 128, 3690 ZUTENDAAL, BE
# ()
#
# HEESAKKERSTRAAT 1 ., 3900 OVERPELT, BE
# ()
#
#
# ()
#
#
# ()
#
# SAVAANSTRAAT, 33, 9000 GENT, BE
# ()
#
# RUE DES FONTAINES 32, 4360 OREYE, BE
# ()
#
#
# ()
#
# VOORT 12, 3910 NEERPELT, BE
# ()
#
# NEDERSTRAAT 97, 3730 HOESELT, BE
# ()
#
# KNAPKOEKSTRAAT 10, 3680 MAASEIK, BE
# ()
#
# HEMELINGENSTRAAT 53, 3700 TONGEREN, BE
# ()
#
# HEMELINGENSTRAAT 53, 3700 TONGEREN, BE
# ()
#
# RUE LAMBERT DEWONCK, 8, 4452 WIHOGNE, BE
# ()
#
# ST. JOZEFSTRAAT 5, 3740 BILZEN, BE
# ()
#
# HERENSTRAAT, 3730 HOESELT, BE
# ()
#
#
# ()
#
# LINDERSTRAAT139 139U, 3700 TONGEREN, BE
# ()
#
# KAPELSTRAAT 6, 3770 KANNE, BE
# ()
#
# VOORTWEG 1, 3950 BOCHOLT, BE
# ()
#
# KETELLAPPERSSTRAAT 68, 3950 BOCHOLT, BE
# ()
#
# DWARSSTRAAT 2 GVA 3, 8490 JABBEKE, BE
# ()
#
# KETELLAPPERSSTRAAT 68, 3950 BOCHOLT, BE
# ()
#
# DONKSTRAAT 22, 3740 BILZEN, BE
# ()
#
# SINT PIETERSSTRAAT 92, 3630 MAASMECHELEN, BE
# ()
#
#
# ()
#
# SLUIZERBROEK 39, 3700 SLUIZEN TONGEREN, BE
# ()
#
# WIJNGAARDSTRAAT 18 BUS 1.1, 3740 MUNSTERBILZEN, BE
# ()
#
# KLEESTRAAT NR 9, 3840 BORGLOON, BE
# ()
#
#
# ()
#
# ASSERWEG 128, 36390 ZUTENDAAL, BE
# ()
#
#
# ()
#
# DES CHARDONNERETS 31, 5310 LEUZE, BE
# ()
#
# GERSTSTRAAT 13, 8400 OOSTENDE, BE
# ()
#
# WEERTERSTEENWEG  141, 3640 KINROOI, BE
# ()
#
# KERSENDAELSTRAAT 81, 3724 VLIERMAAL, BE
# ()
#
# SCHABBERTENSTRAAT 18, 3630 MAASMECHELEN, BE
# ()
#
# WEERTERSTEENWEG  141, 3640 KINROOI, BE
# ()
#
# HOEVERWEG 87, 3660 OPGLABBEEK, BE
# ()
#
# ZAVELSTRAAT, 3990 KLEINE BROGEL, BE
# ()
#
#
# ()
#
#
# ()
#
# KLEINSTRAAT 27, 3500 HASSELT, BE
# ()
#
# RIJSBERGDIJK 4, 2490 BALEN, BE
# ()
#
# BASTIAENSSTRAAT 38A, 3700 TONGEREN, BE
# ()
#
# ASTRIDLAAN 115 BUS 1, 3900 OVERPELT, BE
# ()
#
# ALLÉE DES COLZAS 51, 1160 BRUXELLES, BE
# ()
#
# MENNESTRAAT, 3770 RIEMST, BE
# ()
#
# HONSDRIES 27, 3640 KINROOI, BE
# ()
#
# PASTOOR WINTERSSTRAAT 2, 3770 RIEMST, BE
# ()
#
#
# ()
#
#
# ()
#
# HOSSENSTRAAT 32, 3700 TONGEREN, BE
# ()
#
# KONINKSEMSTEENWEG 38, 3700 TONGEREN, BE
# ()
#
# GREMELSLOWEG 62, 3680 MAASEIK, BE
# ()
#
#
# ()
#
# DE BORMANLAAN 33, 3730 HOESELT, BE
# ()
#
#
# ()
#
# HOEVEWEG 176, 3650 LANKLAAR, BE
# ()
#
# ONDERSTRAAT, 3730 HOESELT, BE
# ()
#
# CUVELIERSTRAAT, 3740 BILZEN, BE
# ()
#
# GROTE STEENWEG 95, 3440 HALLE-BOOIENHOVEN, BE
# ()
#
# CHEMIN DE FALLAIS, 4261 LATINNE, BE
# ()
#
# VIJVERHOEK 9, 9860 OOSTERZELE, BE
# ()
#
# HERENT 35, 3910 NEERPELT, BE
# ()
#
# PLAGGENSTRAAT 51, 3600 GENK, BE
# ()
#
# LUITESTRAAT 1, 3640 KINROOI, BE
# ()
#
# VREDESTRAAT, 3600 GENK, BE
# ()
#
# BOCHOLTERKIEZEL, 3960 BREE, BE
# ()
#
# SNOEKSTRAAT 50, 3570 ALKEN, BE
# ()
#
# JENNENSTRAAT 10, 3950 BOCHOLT, BE
# ()
#
# SINT-LUCIESTRAAT 37, 3631 UIKHOVEN, BE
# ()
#
# GEERKENSVELDSTRAAT 29, 3690 ZUTENDAAL, BE
# ()
#
# VENAKKERSTRAAT, 5552 VALKENSWAARD, NL
# ()
#
# KLEINSTRAAT 13, 3700 TONGEREN, BE
# ()
#
# LANGVELDSTRAAT, 3570 ALKEN, BE
# ()
#
# DRIEVEKKENWEG 60, 3680 NEEROETEREN, BE
# ()
#
# MOLENSTRAAT, 3600 GENK, BE
# ()
#
# MOLENSTRAAT, 3600 GENK, BE
# ()
#
# SIEBERG 6, 3770 RIEMST, BE
# ()
#
# MEIDOORNSTRAAT 32, 3990 PEER, BE
# ()
#
# NEREMSTRAAT 73, 3700 TONGEREN, BE
# ()
#
# HELZOLDSTRAAT 8, 3530 HELCHTEREN, BE
# ()
#
# PATER NEYENSLAAN 34, 3960 BREE, BE
# ()
#
#
# ()
#
# RIBAUCOURT 54, 5590 HAVERSIN, BE
# ()
#
# EETSEVELDSTRAAT 14, 3960 BREE, BE
# ()
#
# VENSTRAAT, 3700 TONGEREN VREREN, BE
# ()
#
# VAESSTRAAT 3, 3960 BREE, BE
# ()
#
# HASSELTSESTRAAT, 3740 BILZEN, BE
# ()
#
#
# ()
#
# BOSWEG 22, 3723 KORTESSEM, BE
# ()
#
# KEMPENSTRAAT 8, 3700 TONGEREN, BE
# ()
#
# BUISSTRAAT, 2890 SINT-AMANDS, BE
# ()
#
# SLACHTHUISSTRAAT, 35 2B, 3680 MAASEIK, BE
# ()
#
# STRIKKELBERG 31 DIETS HEUR TONGEREN, 3700 TONGEREN DIETS HEUR, BE
# ()
#
# GOUDBLOEMSTRAAT, 3960 BREE, BE
# ()
#
# KAPELSTRAAT 4, 3930 HAMONT, BE
# ()
#
# WATERKASTEELSTRAAT 24, 3740 BILZEN, BE
# ()
#
# SINT -TRUIDERSTEENWEG 338, 3700 TONGEREN, BE
# ()
#
# WEG NAAR AS 39 TE, 3600 GENK, BE
# ()
#
#
# ()
#
#
# ()
#
# HEIDERVELDSTRAAT 17, 3665 AS, BE
# ()
#
#
# ()
#
# KEUNENLAAN 6, 3870 HEERS, BE
# ()
#
# PLACE DU MONUMENT, 5, 4340 OTHÉE, BE
# ()
#
# MAASTRICHTERSTRAAT, 3700 TONGEREN, BE
# ()
#
# KRONENBERGSTRAAT 8, 3950 BOCHOLT, BE
# ()
#
# RONDSTRAAT 5, 3640 MOLENBEERSEL, BE
# ()
#
# SCHIPPERSTRAAT 16, 3950 BOCHOLT, BE
# ()
#
# PRINSES PAOLALAAN 61, 3630 MAASMECHELEN, BE
# ()
#
#
# ()
#
# SPARRENWEG 27B, 3520 ZONHOVEN, BE
# ()
#
#
# ()
#
# NIEUWSTRAAT 1 BUS 2, 3910 NEERPELT, BE
# ()
#
# ACHTER DE HOVEN, 3770 RIEMST, BE
# ()
#
# TERWEG, 3680 VOORSHOVEN, BE
# ()
#
# WOUTERBOS 31, 3680 OPOETEREN, BE
# ()
#
# BLAARSTRAAT, 3700 TONGEREN, BE
# ()
#
# EIKENSTRAAT 1, 3670 MEEUWEN, BE
# ()
#
# STEVENSVENNEN 70, 3920 LOMMEL, BE
# ()
#
# RINGLAAN 18, 3950 BOCHOLT, BE
# ()
#
# WEIDESTRAAT 5, 3630 MAASMECHELEN, BE
# ()
#
#
# ()
#
# GROENSTRAAT 17, 3700 TONGEREN, BE
# ()
#
# MAHONIESTRAAT 18, 3530 HOUTHALEN-OOST, BE
# ()
#
# STAPPENVEKKENWEG, 3680 NEEROETEREN, BE
# ()
#
# JAGERSBORGWEG 37, 3680 MAASEIK, BE
# ()
#
# PATER CONINXLAAN 4, 3960 BREE, BE
# ()
#
#
# ()
#
#
# ()
#
# WEG NAAR AS, 3660 OPGLABBEEK, BE
# ()
#
# GRENSSTRAAT 3, 3670 MEEUWEN-GRUITRODE (WIJSHAGEN), BE
# ()
#
#
# ()
#
# TONGERSVELDSTRAAT 26, 3700 TONGEREN, BE
# ()
#
# POSTSTRAAT 16, 3945 KWAADMECHELEN-HAM, BE
# ()
#
#
# ()
#
# NIESSTRAAT, 26, 3680 OPOETEREN (MAASEIK), BE
# ()
#
# HOGER-OPSTRAAT,  MAL, 3700 MAL (TONGEREN), BE
# ()
#
# DORPSSTRAAT 25, 3717 HERSTAPPE, BE
# ()
#
# HENDRIK VAN VELDEKESTRAAT 39, 3680 MAASEIK, BE
# ()
#
# RUE D'EN DESSOUS, 4254 LIGNEY, BE
# ()
#
# DORPSSTRAAT, 3910 NEERPELT, BE
# ()
#
# EMAELERWEG 8, 3770 RIEMST, BE
# ()
#
# ROMERSHOVENSTRAAT 82, 3730 HOESELT, BE
# ()
#
#
# ()
#
# GROOT-GELMENLAAN 9, 3800 SINT-TRUIDEN, BE
# ()
#
#
# ()
#
# STATIONSSTRAAT 36 B7, 3680 MAASEIK, BE
# ()
#
# RIEMSTERWEG 17, 3740 BILZEN, BE
# ()
#
# RIJSBERGDIJK 27, 2490 BALEN, BE
# ()
#
# BARON DE STOCKEMLAAN 21, 3870 HEERS, BE
# ()
#
# KONING BOUDEWIJNSTRAAT, 3940 HECHTEL, BE
# ()
#
# BEEKVELDEN 58 RUMST, 2840 REET, BE
# ()
#
#
# ()
#
# AKKERSTRAAT 112, 3680 MAASEIK, BE
# ()
#
# BRAAMSTRAAT, 3950 BOCHOLT, BE
# ()
#
# STATIONSPLEIN, 3680 MAASEIK, BE
# ()
#
# OLMENWEG 7A, 3959 BOCHOLT, BE
# ()
#
# VAN EYCKLAAN 70, 3680 MAASEIK, BE
# ()
#
# DIESTERSTEENWEG 234, 3680 MAASEIK, BE
# ()
#
#
# ()
#
# GROTLAAN, 3680 NEEROETEREN, BE
# ()
#
# IN DE MOOL 14, 3630 MAASMECHELEN, BE
# ()
#
# DE SCHAETZENGAARDE 26, 3700 TONGEREN, BE
# ()
#
# KNIPSCHEERSTRAAT, 3570 ALKEN, BE
# ()
#
# MOOI UITZICHTLAAN 37, 3740 BILZEN, BE
# ()
#
# HOLLEWEG 97, 3700 VREREN (TONGEREN), BE
# ()
#
#
# ()
#
# O.L.VROUWSTRAAT, 3740 BILZEN, BE
# ()
#
# WEG NAAR AS 165, 3660 OPGLABBEEK, BE
# ()
#
# MOELSTRAAT 16, 3570 ALKEN, BE
# ()
#
#
# ()
#
# HORTENSIASTRAAT 11, 3600 GENK, BE
# ()
#
# KINROOIERSTEENWEG 32, 3680 MAASEIK, BE
# ()
#
# SINT ALDEGONDISSTRAAT 3 BUS 4, 3665 AS, BE
# ()
#
# HOSSENSTRAAT 10, 3700 TONGEREN, BE
# ()
#
# OSCAR HUYSECOMLAAN 11, 3400 LANDEN, BE
# ()
#
# PASTOOR STEENSSENSSTRAAT, 9120 BEVEREN-WAAS, BE
# ()
#
# VISÉSTEENWEG, 3770 RIEMST, BE
# ()
#
# PEPERSTRAAT 52, 3770 MILLEN, BE
# ()
#
# GELINDENSTRAAT, 3870 HEERS, BE
# ()
#
# NAAMSESTEENWEG 229, 3800 SINT-TRUIDEN, BE
# ()
#
# KONING ALBERTLAAN 7, 3680 MAASEIK, BE
# ()
#
# HOLLE HELVERIK 26, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# VERBINDINGSWEG, 3770 VAL-MEER, BE
# ()
#
#
# ()
#
# KORTESTRAAT 11, 3920 LOMMEL, BE
# ()
#
#
# ()
#
# VERBINDINGSWEG, 3770 VAL-MEER, BE
# ()
#
# KAMPSTRAAT 20 HULSBERG, 6336 NUTH, NL
# ()
#
# WURFELDERWEG 104, 3680 MAASEIK, BE
# ()
#
# ZONNELAAN 19, REKEM, 3621 LANAKEN, BE
# ()
#
# RUE DE GAWDAY 88, 5300 MAIZERET, BE
# ()
#
# SCHOOLSTRAAT, 29,3590, 3599 DIEPENBEEK, BE
# ()
#
# LETERWEG, 3740 BILZEN, BE
# ()
#
# KEYARTSTRAAT 28A, 3960 BREE, BE
# ()
#
# BREEËRSTEENWEG 333, 3640 KINROOI, BE
# ()
#
# VEESTRAAT  18,  NEEROETEREN, 3680 3680 NEEROETEREN, BE
# ()
#
# STATIONSSTRAAT 48, 3910 NEERPELT, BE
# ()
#
# DORPSSTRAAT 39A, 3650 LANKLAAR, BE
# ()
#
# HELSHOVENSTRAAT 17, 3840 BORGLOON, BE
# ()
#
# OUDE ASSERWEG77, 3660 OPGLABBEEK, BE
# ()
#
# STEENWEG, 187A, 3870 HEERS, BE
# ()
#
# SALIESTRAAT, 3990 PEER, BE
# ()
#
# RUE HENRI DUNANT 48, 7700 MOUSCRON, BE
# ()
#
#
# ()
#
# RUE SOUS LES ROCHES 16, 4500 HUY, BE
# ()
#
# BRUGSTRAAT BOCHOLT, 3950 , BE
# ()
#
# CLERCXHOEVESTRAAT, 3910 NEERPELT, BE
# ()
#
# STADIONPLEIN 4, 3600 GENK, BE
# ()
#
# KIEWITSEWEG 3, 3690 ZUTENDAAL, BE
# ()
#
# POPULIERENLAAN, 3621 REKEM-LANAKEN, BE
# ()
#
# KNAPENHOEF, 3920 LOMMEL, BE
# ()
#
# VERHENIS 59, 3700 TONGEREN, BE
# ()
#
# VERHENIS 59, 3700 TONGEREN, BE
# ()
#
# STEENWEG 103, 3621 REKEM, BE
# ()
#
# BOSSTRAAT 17 ROSMEER-BILZEN, 3740 BILZEN-ROSMEER, BE
# ()
#
#
# ()
#
# WINTERSTRAAT, 3740 BILZEN, BE
# ()
#
# SCHOTERWEG 354, 3980 TESSENDERLO, BE
# ()
#
# WEG NAAR AS, 3660 OPGLABBEEK, BE
# ()
#
# DORPSSTRAAT 10, 3700 TONGEREN, BE
# ()
#
# RUE DU CHÂTEAU 28, 1450 BLANMONT, BE
# ()
#
# RUE NICOLAS FASTRÉ 7, 4340 VILLERS-L'EVÊQUE, BE
# ()
#
# AMBIORIXLAAN  2, 3621 REKEM, BE
# ()
#
# MOOI UITZICHTLAAN 37, 3740 BILZEN, BE
# ()
#
# DORPSSTRAAT 20/3, 3670 MEEUWEN-GRUITRODE, BE
# ()
#
#
# ()
#
# LETERWEG 22 B, 3740 BILZEN, BE
# ()
#
# KERKSTRAAT, 3630 MAASMECHELEN, BE
# ()
#
#
# ()
#
#
# ()
#
# STRAAT 58, 3870 OPHEERS, BE
# ()
#
# GROOT-GELMENLAAN 85 B, 3800 SINT-TRUIDEN, BE
# ()
#
# MERKENSTRAAT 53, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# DRIETAK 79,   KESSENICH, 3640 KINROOI, BE
# ()
#
# HIMPEDELSTRAAT 11, 3870 HEERS, BE
# ()
#
# ST TRUIDERSTEENWEG 219, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# MOLENSTRAAT, 3950 KAULILLE, BE
# ()
#
# DORPSSTRAAT 5, 3930 ACHEL, BE
# ()
#
#
# ()
#
# GERSTSTRAAT 44, 3930 HAMONT, BE
# ()
#
# GROTE KERKSTRAAT 13 / 21 ., 3680 MAASEIK, BE
# ()
#
# SCHIETSKUILSTRAAT 3, 3630 MAASMECHELEN, BE
# ()
#
# DE GRUNNESTRAAT 6, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# SINT-OOLSTTAAT, 3680 OPOETEREN, BE
# ()
#
# AKKERSTRAAST 15, 3600 GENK, BE
# ()
#
# ZONHOEVESTRAAT 9 BEVERST-, 3740 BILZEN, BE
# ()
#
# MATHIAS GEYSENSTRAAT 74, 3582 KOERSEL, BE
# ()
#
# RUE GÉNÉRAL LENS 3, 4360 LENS SUR GEER, BE
# ()
#
# KRUIDENLAAN 17, 3600 GENK, BE
# ()
#
# HEIRSTRAAT 527, 3620 MAASMECHELEN, BE
# ()
#
#
# ()
#
# HEIRSTRAAT 527, 3620 MAASMECHELEN, BE
# ()
#
#
# ()
#
# LEOPOLDPLEIN, 3630 MAASMECHELEN, BE
# ()
#
# MEREMWEG, 3740 BILZEN, BE
# ()
#
#
# ()
#
#
# ()
#
#
# ()
#
# IRISSTRAAT, 3660 OPGLABBEEK, BE
# ()
#
# WIELEWAALSTRAAT 8, 3700 TONGEREN, BE
# ()
#
# HOEKSTRAAT, 3770 RIEMST GENOELSELDEREN., BE
# ()
#
# RUE JOSEPH DELMOTTE, 66, 4340 FOOZ, BE
# ()
#
# GEENSSTRAAT 27, 3660 OPGLABBEEK, BE
# ()
#
# BREEËRSTEENWEG 385, 3640 KINROOI, BE
# ()
#
#
# ()
#
# RODENBACHLAAN, 3900 , BE
# ()
#
#
# ()
# BOSSCHELWEG 20, 3950 BOCHOLT, BE
# ()
#
# OUDE KERKHOWEG, 3700 TONGEREN, BE
# ()
#
#
# ()
#
#
# ()
#
#
# ()
#
#
# ()
#
# RUE DES BROUCKS, 4252 OMAL, BE
# ()
#
# KAPOELSTRAAT 5, 3700 TONGEREN, BE
# ()
#
# SMEETSSTRAAT 43, 3620 LANAKE, BE
# ()
#
# MERELSTRAAT, 3950 BOCHOLT, BE
# ()
#
# BREEMSTRAAT 45, 3650 DILSEN STOKKEM, BE
# ()
#
# THYSLAAN 21 BUS 0204, 3700 TONGEREN, BE
# ()
#
# SCHEYERVELD, 3640 KINROOI, BE
# ()
#
# HOGER-OPSTRAAT 29, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# OUDE ASSERWEG 60, 3660 OPGLABBEEK, BE
# ()
#
#
# ()
#
# ACHTER DE KERK N4, 3700 TONGEREN R EN, BE
# ()
#
# CUVELIERSTRAAT, 3740 BILZEN, BE
# ()
#
# DONKELSTRAAT, 3700 TONGEREN, BE
# ()
#
# BOSSTRAAT 93, 3680 MAASEIK, BE
# ()
#
# ELISABETHWAL 4, 3700 TONGEREN, BE
# ()
#
# DIKKE LINDE 9A, 3640 OPHOVEN, BE
# ()
#
# COUSENSTRAAT, 3660 OPGLABBEEK, BE
# ()
#
# FRANKENHOF 17, 3621 REKEM-LANAKEN BELGIË, BE
# ()
#
# RUE AUX RAINES 76, 4537 CHAPON SERAING, BE
# ()
#
# METSTERENWEG 131, 3800 SINT-TRUIDEN, BE
# ()
#
# MEULEMANSLAAN, 3700 TONGEREN, BE
# ()
#
# NEEROETERSESTEENWEG, 3640 KINROOI, BE
# ()
#
# NEEROETERSESTEENWEG, 3640 KINROOI, BE
# ()
#
# KONINGIN ASTRIDLAAN, 88, 3680 MAASEIK, BE
# ()
#
# BOEKWEITSTRAAT 2B, 3660 OPGLABBEEK, BE
# ()
#
# RUE WARNOTTE 2, 4317 FAIMES, BE
# ()
#
# AMBIORIXSTRAAT 54, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# KROMSTRAAT 7, 3770 RIEMST, BE
# ()
#
# HEUVELSTRAAT 54/4, 3620 LANAKEN, BE
# ()
#
# MEEUWERKIEZEL 51, 3960 BREE, BE
# ()
#
#
# ()
#
# BINKELSTRAAT 1, 3700 NEERREPEN, BE
# ()
#
# VISÉWEG, 3700 TONGEREN, BE
# ()
#
# BREEËRSTEENWEG 79, 3640 KINROOI KESSENICH, BE
# ()
#
#
# ()
#
# VERBINDINGSSTRAAT, 3960 OPITTER, BE
# ()
#
# DWARSSTRAAT 4, 3910 NEERPELT, BE
# ()
#
#
# ()
#
#
# ()
#
# KALLERSTRAAT 32, 3950 BOCHOLT, BE
# ()
#
# HASSELTSESTEENWEG 5, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# MAASTRICHTERSTEENWEG 37, 3700 TONGEREN, BE
# ()
#
# BUKERSMOULT 14, 3770 HERDEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# RAADHUISSTRAAT 6, 6077 SINT ODILIËNBERG, NL
# ()
#
# VISSERSTRAAT, 3650 , BE
# ()
#
#
# ()
#
# NIEUWSTADPOORT 7 A005, 3960 BREE, BE
# ()
#
# BLAATSTRAAT 140, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# ACACITRAAT, 3665 AS, BE
# ()
#
# WILLIEBRORDUSWEG 5, 3680 MAASEIK, BE
# ()
#
# ROOI 19, 3740 BILZEN, BE
# ()
#
# ROUTE DE FRASNES 150/A, 7860 LESSINES, BE
# ()
#
# LINNERHOF, 3742 MARTENSLINDE, BE
# ()
#
# VOSTERRSTRAAT 16, 3962 BREE, BE
# ()
#
# BREEËRWEG, 3950 BOCHOLT, BE
# ()
#
#
# ()
#
# HOSPITAALSTRAAT, 3740 BILZEN, BE
# ()
#
# ROTERSTRAAT, 3960 BREE, BE
# ()
#
# POOTHOFSTRAAT 4, 3742 MARTENSLINDE, BE
# ()
#
# HASSELTSESTRAAT, 3740 BILZEN, BE
# ()
#
# JAKOBSSTRAAT 25, 3700 'S HERENELDEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# BIJSSTRAAT, 3770 VLIJTINGEN, BE
# ()
#
# MOLENSTRAAT 21, 2560 NIJLEN, BE
# ()
#
# HEREBAAN-OOST 124, 3530 HOUTHALEN, BE
# ()
#
# DE GISKENS, 3930 HAMONT, BE
# ()
#
# HONSDRIES 28, 3640 KINROOI, BE
# ()
#
# PRIESTER DAENSSTRAAT, 3620 LANAKEN, BE
# ()
#
# ST - AMANDUSSTRAAT 1, 3400 LANDEN, BE
# ()
#
#
# ()
#
# BERKENLAAN 11, 3960 BREE, BE
# ()
#
# PATERNEYENSLAAN, 3960 BREE, BE
# ()
#
# WURFELDERWEG 90, 3380 MAASEIK, BE
# ()
#
# MOLENDRIESSTRAAT 10 A, 3740 EIGENBILZEN, BE
# ()
#
# LINDERSTRAAT 79, 3700 TONGEREN, BE
# ()
#
# LINDENLAAN 25, 3680 MAASEIK, BE
# ()
#
# JOSEPH DÉSIR 66, 4350 MOMALLE, BE
# ()
#
# VOLDERSSTRAAT 30, 2800 MECHELEN, BE
# ()
#
# RAPERTINGENSTRAAT 33, 3500 HASSELT, BE
# ()
#
# VAN EYCKLAAN 5, 3680 MAASEIK, BE
# ()
#
# ROMEINSE KASSEI 239., 3700 TONGEREN, BE
# ()
#
# HENEBERG, HERDEREN (), 3770 RIEMST, BE
# ()
#
#
# ()
#
# WEG NAAR ZWARTBERG 144A, 3660 OPGLABBEEK, BE
# ()
#
# BROEDERSGAARDE 28, 3700 TONGEREN, BE
# ()
#
# KRUISVENLAAN 31, 3650 DILSEN-STOKKEM, BE
# ()
#
# KLEINE HULST 30/5, 3630 MAASMECHELEN, BE
# ()
#
# AVENUE DE L'IDÉAL 54, 1200 BRUXELLES, BE
# ()
#
# MEINEKOMSTRAAT NAAST DE MAAS, 3640 OPHOVEN, BE
# ()
#
# ONDERSTRAAT 30  KANNE, 3770 RIEMST, BE
# ()
#
# SPORTPLEINSTRAAT, 3800 SINT-TRUIDEN ZEPPEREN, BE
# ()
#
# RUE JULE LISEIN, 9 -  HANNUT (LENS-SAIN-REMY), 4280 4280 HANNUT (LENS-SAINT-REMY), BE
# ()
#
# BAVOSTRAAT 15, 3550 HEUSDEN-ZOLDER, BE
# ()
#
#
# ()
#
# FREDERIK MALDERSSTRAAT, 3680 MAASEIK, BE
# ()
#
# SCHANSSTRAAT 2, 3665 AS, BE
# ()
#
#
# ()
#
# VENSTRAAT 14, 3700 TONGEREN, BE
# ()
#
# KLEINE RAUWSTRAAT, 3A, 3870 HEERS, BE
# ()
#
# RUE DE WAREMME 74, 4257 BERLOZ, BE
# ()
#
# GERDINGERPOORT 1, 3960 BREE - CENTRUM, BE
# ()
#
# SCHEYMANSHOF 18, 3640 KINROOI, BE
# ()
#
# 1 RUE DELWAIDE, 4681 HERMALLE SOUS ARGENTEAU, BE
# ()
#
# STATIONSSTRAAT 50, 3910 NEERPELT, BE
# ()
#
# WILLEM MATSTRAAT 30, 1560 HOEILAART, BE
# ()
#
# KERKSTRAAT 10, 3500 HASSELT, BE
# ()
#
# DEMERSTRAAT, 46, 3770 RIEMST, BE
# ()
#
# ROMERSHOVENSTRAAT 70, 3733 HOESELT, BE
# ()
#
# LEERLOOIERSSTRAAT 8, 3930 HAMONT-ACHEL, BE
# ()
#
# GROTESTRAAT 130, 3631 BOORSEM MAASMECHELEN, BE
# ()
#
#
# ()
#
# STRAMPROYERWEG 22, 3950 BOCHOLT, BE
# ()
#
# NOUVELLE ROUTE, 4432 XHENDREMAEL, BE
# ()
#
# HERDEREN, 3770 RIEMST, BE
# ()
#
# RINGBOOMSTRAAT 23/1, 3770 RIEMST, BE
# ()
#
# OUDE ASSER WEG, 3660 OPGLABBEEK, BE
# ()
#
# KAPELVELDSTRAAT, 3690 ZUTENDAAL, BE
# ()
#
# KREKELGRACHTSTRAAT 18 -, 3770 RIEMST, BE
# ()
#
# STEVOORTSTRAAT 39, 3850 KOZEN, BE
# ()
#
# HONTSEINDESTRAAT 8, 9981 SINT-MARGRIETE, BE
# ()
#
# WATERLOZEWEG 32/1, 3680 NEEROETEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# HEIRSTRAAT 240, 3630 MAASMECHELEN, BE
# ()
#
#
# ()
#
#
# ()
#
# MAASTRICHTERSTEENWEG 180, 3700 TONGEREN, BE
# ()
#
# RUE DU BUCQ, 59, 7090 STEENKERQUE, BE
# ()
#
# ELZENSTRAAT 79, 3950 BOCHOLT, BE
# ()
#
# RUE NICOLAS LENOIR 34, 4340 VILLERS L'EVÊQUE, BE
# ()
#
#
# ()
#
# BAMPSLAAN 30, 3500 HASSELT, BE
# ()
#
# BAVERSSTRAAT 53, 3700 TONGEREN, BE
# ()
#
# TOEKOMSTRAAT, 3640 KINROOI, BE
# ()
#
# KASTEELDREEF 29B2, 3930 ACHEL, BE
# ()
#
# HAVERSTRAAT 75, 3930 HAMONT, BE
# ()
#
# SPARRENLAAN 4, 3730 HOESELT, BE
# ()
#
#
# ()
#
# ZANDBERGERSTRAAT 60, 3680 NEEROETEREN, BE
# ()
#
# RUE SOUS-LES-MONTS, 4, 4280 PETIT-HALLET, BE
# ()
#
# BLOESEMSTRAAT, 3840 BORGLOON, BE
# ()
#
# GELLIKERWEG 130, 3620 LANAKEN, BE
# ()
#
#
# ()
#
# LEEUWERIKSTRAAT 33, 3660 OPGLABBEEK, BE
# ()
#
# PASTORIJSTRAAT 17 BUS 0.2, 3740 GROTE-SPOUWEN, BE
# ()
#
# COLLEGELAAN 11, 3990 PEER, BE
# ()
#
# VREDESTRAAT 57, 3600 GENK, BE
# ()
#
# DE BEMMERT, 3910 NEERPELT, BE
# ()
#
# ROBIJNSTRAAT 17, 3960 BREE, BE
# ()
#
# KASTEELSTRAAT, 3723 KORTESSEM, BE
# ()
#
# BOELEHOEF, 3910 NEERPELT, BE
# ()
#
# MOLENWEG 117, 6225 MAASTRICHT, NL
# ()
#
# KANTSTRAAT, 2480 DESSEL, BE
# ()
#
# BERKENDIJK, 3680 OPOETEREN, BE
# ()
#
# WEERTERWEG 57, 3950 BOCHOLT, BE
# ()
#
# VAESSTRAAT 3, 3960 BREE, BE
# ()
#
#
# ()
#
# AMBIORIXSTRAAT 3, 3700 TONGEREN, BE
# ()
#
# HENISSTRAAT 173, 3700 TONGEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# MUNTSTRAAT 12, 3670 MEEUWEN, BE
# ()
#
# MUIZENSTRAAT, 3520 ZONHOVEN, BE
# ()
#
#
# ()
#
# BERGEINDESTRAAT 28, 3680 OPOETEREN, BE
# ()
#
# LETEN 4A, 3740 BILZEN-RIJKHOVEN, BE
# ()
#
# NIEUWE BAAN 2, 3730 HOESELT, BE
# ()
#
#
# ()
#
#
# ()
#
# OUDEWEG 45, 3770 KANNE (RIEMST), BE
# ()
#
# LINDESTRAAT 19, 3910 SINT-HUIBRECHTS-LILLE, BE
# ()
#
# HELSTRAAT, 3721 VLIERMAALROOT, BE
# ()
#
#
# ()
#
# HAMONTERWEG 189, 3930 ACHEL, BE
# ()
#
# LEEMKUILSTRAAT, 3570 ALKEN, BE
# ()
#
# SCHOOLSTRAAT 51, 3650 DILSEN-STOKKEM, BE
# ()
#
# OPPERVELDSTR 52, 3630 MAASMECHELEN, BE
# ()
#
# DRIEHOEVENSTRAAT 6, 3960 BREE, BE
# ()
#
#
# ()
#
# TONGERSESTEENWEG 203, 3770 RIEMST, BE
# ()
#
# ROODAKKERSTRAAT 20, 3960 BREE, BE
# ()
#
# KANAALSTRAAT, 3770 RIEMST, BE
# ()
#
# KEISTRAAT 29, 3740 BILZEN, BE
# ()
#
# TOMSTRAAT 34, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# KRUIDENLAAN 46, 3600 GENK, BE
# ()
#
#
# ()
#
# DENNENSTRAAT, 3670 WIJSHAGEN, BE
# ()
#
# BONGAERTSHOF 7, 3770 MILLEN, BE
# ()
#
# DORPSSTRAAT 52, 3730 HOESELT, BE
# ()
#
#
# ()
#
# KAZERNELAAN 77 BUS 01.3, 3530 HOUTHALEN-HELCHTEREN, BE
# ()
#
# HAZENSTRAAT 23, 3630 MAASMECHELEN, BE
# ()
#
# WEERSTANDERSSTRAAT 36, 3870 HEERS, BE
# ()
#
# KONINGIN ASTRIDLAAN, 3680 MAASEIK, BE
# ()
#
# BRONSTRAAT, 3891 GINGELOM, BE
# ()
#
#
# ()
#
# HASSELTSESTEENWEG 296, 3700 TONGEREN, BE
# ()
#
# ROBIJNSTRAAT 14, 3960 BREE, BE
# ()
#
# SINT-SEBASTIAANSLAAN 19, 3870 HEERS, BE
# ()
#
# ZIEPSTRAAT 27, 3960 BREE, BE
# ()
#
# TOMBENLAAN 8, 3621 REKEM, BE
# ()
#
# ST. REMIGIUSSTRAAT 20, 3740 BILZEN, BE
# ()
#
# HEIKANTWEG 11, 3680 NEEROETEREN, BE
# ()
#
# SPOORWEGSTRAAT, 3665 AS, BE
# ()
#
# RORENWEG 38., 3960 BREE, BE
# ()
#
# MOLENWEG 108B, 3660 OPGLABBEEK, BE
# ()
#
#
# ()
#
#
# ()
#
# MISPAD STR, 21, 3600 GENK, BE
# ()
#
# BORGLAAN 17, 3680 NEEROETEREN, BE
# ()
#
# SPOORWEGSTRAAT, 3600 GENK, BE
# ()
#
# K.ASTRIDPLEIN 2, 3970 LEOPOLDSBURG, BE
# ()
#
# VIJVERSTRAAT 16, 3920 LOMMEL, BE
# ()
#
# BIESTERTSTRAAT 8, 3740 GROTE-SPOUWEN, BE
# ()
#
#
# ()
#
# KLEINE WERFSTRAAT 9, 3630 MAASMECHELEN, BE
# ()
#
# RUE DES COMBATTANTS 10, 4360 OREYE, BE
# ()
#
# ACHTER DE HOVEN, 3740 RIJKHOVEN (B), BE
# ()
#
# HOSPITAALPLEIN 1, 3700 TONGEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# DRIEKRUISENSTRAAT 41, 3700 TONGEREN, BE
# ()
#
# ZWALUWSTRAAT 10, 3960 BREE, BE
# ()
#
# TONGERSVELDSTRAAT 17, 3700 TONGEREN, BE
# ()
#
# ST-MARTENPLEIN, 3800 ST-TRUIDEN, BE
# ()
#
#
# ()
#
# BIESTERTSTRAAT,  GROTE-SPOUWEN, 3740 BILZEN, BE
# ()
#
# RUE DU PONT 7, 4257 BERLOZ, BE
# ()
#
# RUE ADOLPHE BRAAS 26, 4317 FAIMES, BE
# ()
#
# REGENTWIJK 8, 3890 GINGELOM, BE
# ()
#
# RIDDERSBAAN, 3668 NIEL-BIJ-AS, BE
# ()
#
#
# ()
#
# MEIGAAR 13, 3800 SINT-TRUIDEN, BE
# ()
#
#
# ()
#
# LINDELAAN , 2, 1730 ASSE, BE
# ()
#
#
# ()
#
#
# ()
#
# DIJKWEG 3, 3680 MAASEIK, BE
# ()
#
# ROERSTRAAT 58, 3600 GENK, BE
# ()
#
# KAPELSTRAAT 15, 3940 HECHTEL-EKSEL, BE
# ()
#
# SINT-TRUIDERSTRAAT, 3700 TONGEREN, BE
# ()
#
# ERASMUSSTRAAT 33 SITTARD, 6136 SITTARD-GELEEN, NL
# ()
#
# ACHTERSTRAAT 35, 3700 TONGEREN, BE
# ()
#
# ST-TRUIDERSTEENWEG, 3700 TONGEREN, BE
# ()
#
# LOMMELSEBAAN, 3940 HECHTEL, BE
# ()
#
# HEIRBAAN 381 -  REKEM-LANAKEN, 3621 REKEM - LANAKEN, BE
# ()
#
# HEIRBAAN 381 -  REKEM-LANAKEN, 3621 REKEM - LANAKEN, BE
# ()
#
#
# ()
#
# RUE DE HOLLOGNE, 54, 4250 HOLLOGNE-SUR-GEER, BE
# ()
#
# OUDE BERG 1, 3840 BORGLOON, BE
# ()
#
#
# ()
#
#
# ()
#
# RUE DE  83, 4600 LANAYE, BE
# ()
#
# MARETAKSTRAAT, 3600 GENK, BE
# ()
#
# HEURSTRAAT 37, 3700 TONGREN, BE
# ()
#
# QUAI BONAPARTE, 4020 LIÈGE, BE
# ()
#
# EUROPALAAN, 3650 DILSEN, BE
# ()
#
# THUIS MONSSTRAAT 58, 3990 PEER, BE
# ()
#
# KASTANJEWAL 64, 3700 TONGEREN, BE
# ()
#
# D'HEUR, 4340 OTHEE, BE
# ()
#
# 6, RUE DE LIEGE, 4317 FAIMES, BE
# ()
#
# DAALBROEKSTRAAT, 75, 3630 OPGRIMBIE, BE
# ()
#
#
# ()
#
# NANOVESTRAAT, 1745 OPWIJK, BE
# ()
#
# MAASTRICHTERSSTEENWEG 117, 3700 TONGEREN, BE
# ()
#
# ROMEINENDREEF 26, 3620 LANAKEN, BE
# ()
#
# GIERENSSTRAAT, 3600 GENK, BE
# ()
#
# KRUIDENLAAN 56., 3600 GENK, BE
# ()
#
# LAUWSTRAAT 93, 3700 TONGEREN, BE
# ()
#
# MGR.GUBBELSSTRAAT, 3630 MAASMECHELEN, KOTEM, BE
# ()
#
# BETONWEG 35, 3670 ELLIKOM, BE
# ()
#
# KLOOSTERSTRAAT 2, 3800 GROOT-GELMEN, BE
# ()
#
# GROOTVEN 10, 3550 ZOLDER, BE
# ()
#
# HANEVELDSTRAAT, 3600 GENK, BE
# ()
#
# GROENSTRAAT 74, 3600 GENK, BE
# ()
#
# KONING ALBERTLAAN, 3680 MAASEIK, BE
# ()
#
#
# ()
#
# KASTANJEWAL 38, 3700 TONGEREN, BE
# ()
#
# CHRYSANTENLAAN 45, 3740 BILZEN, BE
# ()
#
# BEGIJNENSTRAAT 10, 3680 MAASEIK, BE
# ()
#
# BEGIJNENSTRAAT 10, 3680 MAASEIK, BE
# ()
#
#
# ()
#
# TONGERSESTEENWEG, 3730 HOESELT, BE
# ()
#
# HUMBEEKSESTEENWEG, 1850 GRIMBERGEN, BE
# ()
#
# WEERTERSTEENWEG 1, 3640 KINROOI, BE
# ()
#
# BATSSTRAAT 22, 3870 HEERS, BE
# ()
#
# BEVRIJDINGSLAAN, 3665 AS, BE
# ()
#
# WEERTERSTEENWEG 1, 3640 KINROOI, BE
# ()
#
# RUE DU MANIL, 15, 4250 HOLLOGNE SUR GEER, BE
# ()
#
# TOEKOMSTLAAN, 3910 NEERPELT, BE
# ()
#
# RODE KRUISSTRAAT, 3580 BERINGEN, BE
# ()
#
# OUDE BAAN 598, 3630 MAASMECHELEN, BE
# ()
#
# RUE JEAN MAQUOI 6, 4351 HODEIGE, BE
# ()
#
# TIELEMANSTRAAT 9, 3740 BILZEN, BE
# ()
#
#
# ()
#
# KLUISTRAAT 18, 3680 MAASEIK, BE
# ()
#
# EIKENLAAN, 3600 , BE
# ()
#
# MGR TRUDOJANSSTRAAT 27, 3770 RIEMST, BE
# ()
#
# LANGEN EIKEN, 3272 TESTELT, BE
# ()
#
# 'T LO 131,  HAMONT, 3930 HAMONT-ACHEL (BELGIË), BE
# ()
#
# ZANDSTRAAT 10, 8490 VARSENARE, BE
# ()
#
# KLUITSTRAAT 35, 3910 NEERPELT, BE
# ()
#
# RIEMST (HERDEREN) KRUISHERENSTRAAT 27, 3770 HERDEREN (DEELGEMEENTE VAN RIEMST), BE
# ()
#
#
# ()
#
# BRUXELLES, 1180 , BE
# ()
#
# SPARRENSTRAAT 34, 3530 HOUTHALEN, BE
# ()
#
# HOELBEEKSTRAAT 33, BILZEN, 3746 BILZEN (HOELBEEK), BE
# ()
#
#
# ()
#
#
# ()
#
# SPELTSTRAAT 6, 3650 DILSEN-STOKKEM, BE
# ()
#
# MOLENSTRAAT,1, 3870 HEERS, BE
# ()
#
#
# ()
#
# RIJKSWEG 72, 3650 DILSEN-STOKKEM, BE
# ()
#
# DU BÉGUINAGE NUMÉRO 22 BOITE 11, 4432 ANS (XHENDREMAEL), BE
# ()
#
# VENLOSESTEENWEG, 3640 KINROOI, BE
# ()
#
# OP DE KOEL 8, 3665 AS, BE
# ()
#
#
# ()
#
# VAN EYCKLAAN, 3680 MAASEIK, BE
# ()
#
# FRANS CEULEMANSSTRAAT 10, 3740 BILZEN, BE
# ()
#
# EEKHOORNSTRAAT 1, 3670 GRUITRODE, BE
# ()
#
# EEKHOORNSTRAAT 1, 3670 GRUITRODE, BE
# ()
#
# LADDERSTRAAT, 40, 3620 NEERHAREN, BE
# ()
#
# PAARDSKERKHOF 4, 3990 PEER, BE
# ()
#
# RUE DE GLATIGNY, 1360 PERWEZ, BE
# ()
#
# RONDESTRAAT 27, LOZEN, 3950 BOCHOLT, BE
# ()
#
# EINDE 8, 3670 MEEUWEN, BE
# ()
#
# SINT JANSBERG 32, 3680 MAASEIK, BE
# ()
#
# MILLERWEG 24, 3700 TONGEREN, BE
# ()
#
#
# ()
#
# LINDEKAPELSTRAAT 80, 3730 HOESELT, BE
# ()
#
#
# ()
#
# HOLTAPPELTEER, 3830 WELLEN, BE
# ()
#
#
# ()
#
# HASPENGOUWLAAN 18, 3870 HORPMAAL, BE
# ()
#
# RUE DE MONTIGNY, 5380 FORVILLE, BE
# ()
#
# VAN EYCKLAAN 128, 3680 MAASEIK, BE
# ()
#
# VENHOVENSTRAAT 17-, 3670 GRUITRODE, BE
# ()
#
# LINDENLAAN 24, 3680 MAASEIK, BE
# ()
#
# MEIERSTRAAT 25, 3640 KINROOI, BE
# ()
#
# GROTE BAAN 49, 3670 ELLIKOM-MEEUWEN, BE
# ()
#
# BOSSTRAATJE, 3640 KINROOI-KESSENICH, BE
# ()
#
# BIEZENSTRAAT 3, 3680 NEEROETEREN, BE
# ()
#
# VENELLE NOTRE DAME DES CHAMPS, 1300 WAVRE, BE
# ()
#
# GOUVERNEUR VERWILGHENSINGEL 70, 3500 HASSELT, BE
# ()
#
# MAASTRICHTERSTRAAT 315, 3740 BILZEN MOPERTINGEN, BE
# ()
#
# STEENWEG OP VILVOORDE 393, 1745 OPWIJK, BE
# ()
#
# KLEINVELDSTRAAT 40, 3700 VREREN-TONGEREN, BE
# ()
#
# LIETENSTRAAT 12, 3660 OPGLABBEEK, BE
# ()
#
# FABRIEKSTRAAT, 3, 3910 NEERPELT, BE
# ()
#
# HEURSTRAAT, 3700 , BE
# ()
#
# RADIOSTRAAT 85, 3700 TONGEREN, BE
# ()
#
# RIETENSTRAAT 2, 3670 MEEUWEN-GRUITRODE (WIJSHAGEN), BE
# ()
#
#
# ()
#
# BOEBERG, 3700 TONGEREN, BE
# ()
#
# BOEBERG, 3700 TONGEREN, BE
# ()
#
# VEN,62, 3680 MAASEIK, BE
# ()
#
# HASSELBROEKSTRAAT 158, 3890 JEUK, BE
# ()
#
# KAPELLEKENSDREEF 19, 2222 WIEKEVORST, BE
# ()
#
# HERENWEG 24, 3700 TONGEREN, BE
# ()
#
# VLIERSTRAAT 28, 3960 BREE, BE
# ()
#
# DE SCHIJF 30, 3930 HAMONT-ACHEL, BE
# ()
#
# BELLIKSTRAAT, 3650 DILSEN-STOKKEM, BE
# ()
#
# GENENDRIES 35, 3770 RIEMST, BE
# ()
#
# JESSERENSTRAAT, 3840 BORGLOON, BE
# ()
#
# NIEUWE STEENWEG, 3870 HEERS, BE
# ()
#
# ELDERENWEG 26 IN, 3770 MILLEN, BE
# ()
#
# ALLÉE DES COLZAS 51, 1160 AUDERGHEM, BE
# ()
#
# LEBURTON, 8, 4340 VILLERS L'EVÊQUE, BE
# ()
#
# HACCOSTRAAT 6, 3700 TONGEREN, BE
# ()
#
# BAVERSTRAAT 32, 3700 TONGEREN, BE
# ()
#
# RUE DE LA PETITE RÉE , 7, 4210 OTEPPE, BE
# ()
#
# BARRIERSTRAAT 64, 3960 BREE, BE
# ()
#
# SINT-TRUIDERSTEENWEG 307, 3700 TONGEREN, BE
# ()
#
# KABIENSTRAAT 9, 3770 RIEMST - ZICHEN ZUSSEN BOLDER, BE
# ()
#
# NEREMWEG 141, 3700 TONGEREN, BE
# ()
#
# RIJCKERSTRAAT 15, 3770 RIEMST, BE
# ()
#
# WINDVELD 15, 3930 HAMONT, BE
# ()
#
# KANTONSWEG 139B, 3650 DILSEN-STOKKEM, BE
# ()
#
# RUE VERTECOUR, 4690 GLONS, BE
# ()
#
# JASPERSLAAN 9, 3950 KAULILLE, BE
# ()
#
# OP DE DRIES 61 TE, 3770 RIEMST, BE
# ()
#
#
# ()
#
# RUE CHAMPINOTTE 62, 4254 LIGNEY, BE
# ()
#
# BREMAKKER 9, 3740 BILZEN, BE
# ()
#
# HELENA WIJNANTSLAAN, 3870 HEERS, BE
# ()
#
# DES PRES 5, 4360 OREYE, BE
# ()
#
# SLEEDOORNSTRAAT 84, 3530 HOUTHALEN (OOST), BE
# ()
#
# 13 RUE DE LA FORGE, 4360 OTRANGE, BE
# ()
#
# RONDESTRAAT, 3950 BOCHOLT, BE
# ()
#
# SINT-TRUIDERSTEENWEG 440, 3700 TONGEREN, BE
# ()
#
# WEERTERWEG 88, 3950 BOCHOLT, BE
# ()
#
# MOLENSTRAAT 15, 3930 HAMONT, BE
# ()
#
# PETRONELLAHOF, 3621 REKEM, BE
# ()
#
# RUE DOCTEUR COLSON, 1430 REBECQ, BE
# ()
#
#
# ()
#
# SPILSTRAAT, 3680 NEEROETEREN, BE
# ()
#
# TISMANSWEG, 3680 NEEROETEREN, BE
# ()
#
# GROOTROOTPLEIN, 3680 MAASEIK NEEROETEREN, BE
# ()
#
# GROOTROOTPLEIN 11, 3680 MAASEIK, BE
# ()
#
# ASTRIDLAAN 111, 3700 TONGEREN, BE
# ()
#
#
# ()
#
#
# ()
#
# OUDE BAAN 321, 3630 MAASMECHELEN, BE
# ()
#
#
# ()
#
#
# ()
#
# HOOGSTRAAT 103, 8540 DEERLIJK, BE
# ()
#
# SINT-JOZEFSSTRAAT 8, 3730 HOESELT, BE
# ()
#
# PLATTESTRAAT 16, 3830 WELLEN, BE
# ()
#
# JEHENNESTRAAT 31, 3770 RIEMSTZICHEN ZUSSEN BOLDER, BE
# ()
#
# GROENSTRAAT 8, 3740 ROSMEER, BE
# ()
#
# SLACHTHUISSTRAAT 5, 3840 BORGLOON, BE
# ()
#
# PATER CONINXLAAN 5A, 3960 BREE, BE
# ()
#
#
# ()
#
# ZUURBEEMDLAAN 20, 3740 BILZEN, BE
# ()
#
# BOUWELVEN 2, 2280 GROBBENDONK, BE
# ()
#
# EUROPAPLEIN 40 BUS 9, 3620 LANAKEN, BE
# ()
#
# HAMSTRAAT 43  HOEPERTINGEN, 3840 BORGLOON (HOEPERTINGEN), BE
# ()
#
# BRUGGESTRAAT 12, 3730 HOESELT, BE
# ()
#
# NEREMSTRAAT 87, 3700 TONGEREN, BE
# ()
#
# HUYLSTRAAT 16, 3971 HEPPEN, BE
# ()
#
#
# ()
#
# NIEUWSTRAAT 35, 3950 BOCHOLT, BE
# ()
#
# HELLINGSTRAAT 60, 3620 LANAKEN, BE
# ()
#
# SCHIPPERSSTRAAT, 3620 LANAKEN, BE
# ()
#
# BERDENWEG 6, 2288 BOUWEL, BE
# ()
#
# ZWALUWSTRAAT 18, 3960 OPITTER, BE
# ()
#
# ARNOLD SAUWENLAAN, 3650 STOKKEM, BE
# ()
#
# KASTEELSTRAAT 12, 3730 HOESELT, BE
# ()
#
# DE  84, 4600 RICHELLE, BE
# ()
#
# EUROPALAAN  56 BUS 008, 3650 DILSEN-STOKKEM, BE
# ()
#
# GEORGES CÉSAR, 4300 GRAND-AXHE, BE
# ()
#
# WIJNGAARDSTRAAT, 3740 MUNSTERBILZEN, BE
# ()
#
# NESTOR ROYER, 4367 CRISNEE, BE
# ()
#
# HOUTSTRAAT 9, 3830 WELLEN, BE
# ()
#
# RUE DES COMBATTANTS, 25, 4360 OREYE, BE
# ()
#
#
# ()
#
# CAETSBEEK, 3600 GENK, BE
# ()
#
# VRUNSTRAAT 117, 3550 HEUSDEN-ZOLDER, BE
# ()
#
# HUBERT DROOGMANSSTRAAT, 3582 BERINGEN, BE
# ()
#
# MAASEIKERBAAN, 3960 OPITTER, BE
# ()
#
# YEREREPP, 0 PPTTUTEO, BE
# ()
#
# EETOUYIP, 0 PIURUOOW, BE
# ()
#
# EETOUYIP, 0 PIURUOOW, BE
# ()
#
# 8, AVENUE DE GASPERI, 1340 OTTIGNIES, BE
# ()
#
# SINT-NIKLAASSTRAAT, 9190 SINT GILLIS WAAS, BE
# ()
#
# OUDE GOD 27, 3621 OUD REKEM, BE
# ()
#
# MEELSTRAAT, 3630 MAASMECHELEN, BE
# ()
#
# HOOGBAAN, 3650 DILSEN-STOKKEM, BE
# ()
#
# KANTONS WEG 3, 3650 DILSEN-STOKKEM, BE
# ()
#
#
# ()
#
# WIESVELDLAAN 2 BUS 12, 3740 BILZEN, BE
# ()
#
# BOVENSTRAAT, 3730 HOESELT, BE
# ()
#
# VOSTERTSTRAAT 77, 3960 BREE, BE
# ()
#
#
# ()
#
#
# ()
#
#
# ()
#
# CAMPSTRAAT, 3670 GRUITRODE, BE
# ()

# %%
m = folium.Map(location=[eq.lat, eq.lon], zoom_start=12)
#for loc, address in zip(geo_results, dyfi.get_addresses()):
#    if loc:
#        folium.Marker([loc[1], loc[0]], popup=address, tooltip=address).add_to(m)
for loc, address in zip(geo_results2, dyfi.get_addresses()):
    if loc:
        folium.Marker([loc[1], loc[0]], popup=address, tooltip=address, icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
